# %%
# imports
import requests
import os
import pandas as pd

# %% [markdown]
# # Foursquare

# %% [markdown]
# Send a request to Foursquare with a small radius (1000m) for all the bike stations in your city of choice.

# %%
api_key = os.environ["FOURSQUARE_API_KEY"]


url = "https://api.foursquare.com/v3/places/search"

headers = {"accept": "application/JSON"}
headers['Authorization'] = api_key

# params = {
#     'll' : '43.3186,11.3306',
#     'radius': '1000'
# }


params_lst = [{
    'll' : '43.321600,11.327948',
    'radius': '1000'
},
{
    'll' : '43.314554,11.331021',
    'radius': '1000'
},
{
    'll' : '43.316539,11.337212',
    'radius': '1000'
},
{
    'll' : '43.320523,11.323225',
    'radius': '1000'
},
{
    'll' : '43.328983,11.321913',
    'radius': '1000'
},
{
    'll' : '43.317187,11.354256',
    'radius': '1000'
},
{
    'll' : '43.341757,11.305010',
    'radius': '1000'
},
{
    'll' : '43.343243,11.326733',
    'radius': '1000'
},
{
    'll' : '43.336999,11.300975',
    'radius': '1000'
},
{
    'll' : '43.323781,11.338891',
    'radius': '1000'
},
{
    'll' : '43.347800,11.326046',
    'radius': '1000'
},
{
    'll' : '43.332288,11.324176',
    'radius': '1000'
},
{
    'll' : '43.341445,11.312348',
    'radius': '1000'
},
{
    'll' : '43.326764,11.333702',
    'radius': '1000'
},
{
    'll' : '43.309896,11.315263',
    'radius': '1000'
},
{
    'll' : '43.317315,11.332998',
    'radius': '1000'
},
{
    'll' : '43.296856,11.334854',
    'radius': '1000'
},
{
    'll' : '43.343407,11.322849',
    'radius': '1000'
},
{
    'll' : '43.334640,11.304803',
    'radius': '1000'
}]
response = requests.get(url, params=params, headers=headers)
res_json = response.json()
res_json['results']
# Out:
# [{'fsq_id': '4cadcb06bf70236a139502f9',
#   'categories': [{'id': 13034,
#     'name': 'Café',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#      'suffix': '.png'}}],
#   'chains': [],
#   'distance': 28,
#   'geocodes': {'drop_off': {'latitude': 43.318875, 'longitude': 11.330857},
#    'main': {'latitude': 43.318743, 'longitude': 11.330954},
#    'roof': {'latitude': 43.318743, 'longitude': 11.330954}},
#   'link': '/v3/places/4cadcb06bf70236a139502f9',
#   'location': {'address': 'Via di Città 13',
#    'admin_region': 'Toscana',
#    'country': 'IT',
#    'cross_street': '',
#    'formatted_address': 'Via di Città 13, 53100 Siena Toscana',
#    'locality': 'Siena',
#    'postcode': '53100',
#    'region': 'Toscana'},
#   'name': 'Caffè Fiorella',
#   'related_places': {},
#   'timezone': 'Europe/Rome'},
#  {'fsq_id': '4bcaeef5fb84c9b612ed1d3e',
#   'categories': [{'id': 16041,
#     'name': 'Plaza',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/plaza_',
#      'suffix': '.png'}}],
#   'chains': [],
#   'distance': 79,
#   'geocodes': {'main': {'latitude': 43.318575, 'longitude': 11.331696}},
#   'link': '/v3/places/4bcaeef5fb84c9b612ed1d3e',
#   'location': {'address': 'Piazza del Campo',
#    'admin_region': 'Toscana',
#    'country': 'IT',
#    'formatted_address': 'Piazza del Campo, 53100 Siena Toscana',
#    'locality': 'Siena',
#    'postcode': '53100',
#    'region': 'Toscana'},
#   'name': 'La Birreria Piazza del Campo',
#   'related_places': {},
#   'timezone': 'Europe/Rome'},
#  {'fsq_id': '536b72dd498eec4c5ec04008',
#   'categories': [{'id': 13387,
#     'name': 'Winery',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/winery_',
#      'suffix': '.png'}}],
#   'chains': [],
#   'distance': 66,
#   'geocodes': {'drop_off': {'latitude': 43.319295, 'longitude': 11.330821},
#    'main': {'latitude': 43.319242, 'longitude': 11.330867},
#    'roof': {'latitude': 43.319242, 'longitude': 11.330867}},
#   'link': '/v3/places/536b72dd498eec4c5ec04008',
#   'location': {'address': 'Via dei Termini 4',
#    'admin_region': 'Toscana',
#    'country': 'IT',
#    'cross_street': '',
#    'formatted_address': 'Via dei Termini 4, 53100 Siena Toscana',
#    'locality': 'Siena',
#    'postcode': '53100',
#    'region': 'Toscana'},
#   'name': 'Prètto Prosciutteria e Convivio',
#   'related_places': {},
#   'timezone': 'Europe/Rome'},
#  {'fsq_id': '4c80df32d92ea0936f313b72',
#   'categories': [{'id': 13064,
#     'name': 'Pizzeria',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#      'suffix': '.png'}},
#    {'id': 13236,
#     'name': 'Italian Restaurant',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#      'suffix': '.png'}}],
#   'chains': [],
#   'distance': 73,
#   'geocodes': {'main': {'latitude': 43.318017, 'longitude': 11.330288},
#    'roof': {'latitude': 43.318017, 'longitude': 11.330288}},
#   'link': '/v3/places/4c80df32d92ea0936f313b72',
#   'location': {'address': 'Piazzetta Bonelli Luigi 2',
#    'admin_region': 'Toscana',
#    'country': 'IT',
#    'cross_street': '',
#    'formatted_address': 'Piazzetta Bonelli Luigi 2, 53100 Siena Toscana',
#    'locality': 'Siena',
#    'postcode': '53100',
#    'region': 'Toscana'},
#   'name': 'Ristorante San Desiderio',
#   'related_places': {},
#   'timezone': 'Europe/Rome'},
#  {'fsq_id': '4c0406f2f56c2d7f56ae1d66',
#   'categories': [{'id': 13046,
#     'name': 'Ice Cream Parlor',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/icecream_',
#      'suffix': '.png'}},
#    {'id': 13065,
#     'name': 'Restaurant',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#      'suffix': '.png'}}],
#   'chains': [],
#   'distance': 102,
#   'geocodes': {'main': {'latitude': 43.319492, 'longitude': 11.331209},
#    'roof': {'latitude': 43.319492, 'longitude': 11.331209}},
#   'link': '/v3/places/4c0406f2f56c2d7f56ae1d66',
#   'location': {'address': '13 Via Banchi di Sopra 11',
#    'address_extended': '13',
#    'admin_region': 'Toscana',
#    'country': 'IT',
#    'cross_street': '',
#    'formatted_address': '13 Via Banchi di Sopra 11, 53100 Siena Toscana',
#    'locality': 'Siena',
#    'postcode': '53100',
#    'region': 'Toscana'},
#   'name': 'Grom',
#   'related_places': {},
#   'timezone': 'Europe/Rome'},
#  {'fsq_id': '4d238b773c026ea8c350844e',
#   'categories': [{'id': 13064,
#     'name': 'Pizzeria',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#      'suffix': '.png'}},
#    {'id': 13236,
#     'name': 'Italian Restaurant',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#      'suffix': '.png'}}],
#   'chains': [],
#   'distance': 43,
#   'geocodes': {'main': {'latitude': 43.318446, 'longitude': 11.330752},
#    'roof': {'latitude': 43.318446, 'longitude': 11.330752}},
#   'link': '/v3/places/4d238b773c026ea8c350844e',
#   'location': {'address': 'Piazza Il Campo 29',
#    'admin_region': 'Toscana',
#    'country': 'IT',
#    'cross_street': '',
#    'formatted_address': 'Piazza Il Campo 29, 53100 Siena Toscana',
#    'locality': 'Siena',
#    'postcode': '53100',
#    'region': 'Toscana'},
#   'name': 'Osteria La Mossa',
#   'related_places': {},
#   'timezone': 'Europe/Rome'},
#  {'fsq_id': '4e91bd4b29c2117fa44d1693',
#   'categories': [{'id': 16046,
#     'name': 'Scenic Lookout',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/sceniclookout_',
#      'suffix': '.png'}}],
#   'chains': [],
#   'distance': 129,
#   'geocodes': {'main': {'latitude': 43.317431, 'longitude': 11.329974},
#    'roof': {'latitude': 43.317431, 'longitude': 11.329974}},
#   'link': '/v3/places/4e91bd4b29c2117fa44d1693',
#   'location': {'address': 'Piazza Iacopo della Quercia 1',
#    'admin_region': 'Toscana',
#    'country': 'IT',
#    'cross_street': '',
#    'formatted_address': 'Piazza Iacopo della Quercia 1, 53100 Siena Toscana',
#    'locality': 'Siena',
#    'postcode': '53100',
#    'region': 'Toscana'},
#   'name': 'Panorama dal Facciatone',
#   'related_places': {'parent': {'fsq_id': '4d81deb9d95df04d3b304bbc',
#     'name': "Museo Dell'Opera Del Duomo"}},
#   'timezone': 'Europe/Rome'},
#  {'fsq_id': '4be3debc2fc7d13ad89b083a',
#   'categories': [{'id': 13010,
#     'name': 'Dive Bar',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/divebar_',
#      'suffix': '.png'}},
#    {'id': 13018,
#     'name': 'Pub',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#      'suffix': '.png'}},
#    {'id': 13145,
#     'name': 'Fast Food Restaurant',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/fastfood_',
#      'suffix': '.png'}}],
#   'chains': [],
#   'distance': 51,
#   'geocodes': {'main': {'latitude': 43.318809, 'longitude': 11.331085},
#    'roof': {'latitude': 43.318809, 'longitude': 11.331085}},
#   'link': '/v3/places/4be3debc2fc7d13ad89b083a',
#   'location': {'address': 'Vicolo San Paolo 2',
#    'admin_region': 'Toscana',
#    'country': 'IT',
#    'cross_street': '',
#    'formatted_address': 'Vicolo San Paolo 2, 53100 Siena Toscana',
#    'locality': 'Siena',
#    'postcode': '53100',
#    'region': 'Toscana'},
#   'name': 'San Paolo Pub',
#   'related_places': {},
#   'timezone': 'Europe/Rome'},
#  {'fsq_id': '4c4f21491b8e1b8d9f6d5228',
#   'categories': [{'id': 13260,
#     'name': 'Tuscan Restaurant',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#      'suffix': '.png'}}],
#   'chains': [],
#   'distance': 87,
#   'geocodes': {'drop_off': {'latitude': 43.319243, 'longitude': 11.33076},
#    'main': {'latitude': 43.319339, 'longitude': 11.330676},
#    'roof': {'latitude': 43.319339, 'longitude': 11.330676}},
#   'link': '/v3/places/4c4f21491b8e1b8d9f6d5228',
#   'location': {'address': 'Via dei Termini 7',
#    'admin_region': 'Toscana',
#    'country': 'IT',
#    'cross_street': 'I Terzi',
#    'formatted_address': 'Via dei Termini 7 (I Terzi), 53100 Siena Toscana',
#    'locality': 'Siena',
#    'postcode': '53100',
#    'region': 'Toscana'},
#   'name': 'Enoteca I Terzi',
#   'related_places': {},
#   'timezone': 'Europe/Rome'},
#  {'fsq_id': '53ad53c6498ee1246592610a',
#   'categories': [{'id': 13039,
#     'name': 'Deli',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/deli_',
#      'suffix': '.png'}},
#    {'id': 13145,
#     'name': 'Fast Food Restaurant',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/fastfood_',
#      'suffix': '.png'}},
#    {'id': 13334,
#     'name': 'Sandwich Spot',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/deli_',
#      'suffix': '.png'}}],
#   'chains': [],
#   'distance': 68,
#   'geocodes': {'main': {'latitude': 43.318941, 'longitude': 11.331347},
#    'roof': {'latitude': 43.318941, 'longitude': 11.331347}},
#   'link': '/v3/places/53ad53c6498ee1246592610a',
#   'location': {'address': 'Vicolo San Pietro',
#    'admin_region': 'Toscana',
#    'country': 'IT',
#    'cross_street': 'Croce Del Travaglio',
#    'formatted_address': 'Vicolo San Pietro (Croce Del Travaglio), 53100 Siena Toscana',
#    'locality': 'Siena',
#    'postcode': '53100',
#    'region': 'Toscana'},
#   'name': 'Te Ke Voi',
#   'related_places': {},
#   'timezone': 'Europe/Rome'}]

# %% [markdown]
# Parse through the response to get the POI (such as restaurants, bars, etc) details you want (ratings, name, location, etc)

# %% [markdown]
# Put your parsed results into a DataFrame

# %% [markdown]
# # Yelp

# %% [markdown]
# Send a request to Yelp with a small radius (1000m) for all the bike stations in your city of choice.

# %% [markdown]
# Parse through the response to get the POI (such as restaurants, bars, etc) details you want (ratings, name, location, etc)

# %% [markdown]
# Put your parsed results into a DataFrame

# %% [markdown]
# # Comparing Results

# %% [markdown]
# Which API provided you with more complete data? Provide an explanation.

# %% [markdown]
# Get the top 10 restaurants according to their rating
