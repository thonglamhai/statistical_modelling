# %%
# imports
import requests
import os
import pandas as pd

# %% [markdown]
# # Foursquare

# %% [markdown]
# Send a request to Foursquare with a small radius (1000m) for all the bike stations in your city of choice.

# %%
api_key = os.environ["FOURSQUARE_API_KEY"]


url = "https://api.foursquare.com/v3/places/search"

headers = {"accept": "application/JSON"}
headers['Authorization'] = api_key

# params = {
#     'll' : '43.3186,11.3306',
#     'radius': '1000'
# }


params_lst = [{
    'll' : '43.321600,11.327948',
    'radius': '1000'
},
{
    'll' : '43.314554,11.331021',
    'radius': '1000'
},
{
    'll' : '43.316539,11.337212',
    'radius': '1000'
},
{
    'll' : '43.320523,11.323225',
    'radius': '1000'
},
{
    'll' : '43.328983,11.321913',
    'radius': '1000'
},
{
    'll' : '43.317187,11.354256',
    'radius': '1000'
},
{
    'll' : '43.341757,11.305010',
    'radius': '1000'
},
{
    'll' : '43.343243,11.326733',
    'radius': '1000'
},
{
    'll' : '43.336999,11.300975',
    'radius': '1000'
},
{
    'll' : '43.323781,11.338891',
    'radius': '1000'
},
{
    'll' : '43.347800,11.326046',
    'radius': '1000'
},
{
    'll' : '43.332288,11.324176',
    'radius': '1000'
},
{
    'll' : '43.341445,11.312348',
    'radius': '1000'
},
{
    'll' : '43.326764,11.333702',
    'radius': '1000'
},
{
    'll' : '43.309896,11.315263',
    'radius': '1000'
},
{
    'll' : '43.317315,11.332998',
    'radius': '1000'
},
{
    'll' : '43.296856,11.334854',
    'radius': '1000'
},
{
    'll' : '43.343407,11.322849',
    'radius': '1000'
},
{
    'll' : '43.334640,11.304803',
    'radius': '1000'
}]


# response = requests.get(url, params=params, headers=headers)
# res_json = response.json()
# res_json['results']
res_json_lst = []
for params in params_lst:
    response = requests.get(url, params=params, headers=headers)
    res_json = response.json()
    res_json_lst.append(res_json)

res_json_lst[0]
# Out:
# {'results': [{'fsq_id': '5958042f35d3fc2a960473c7',
#    'categories': [{'id': 13064,
#      'name': 'Pizzeria',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'distance': 23,
#    'geocodes': {'main': {'latitude': 43.321406, 'longitude': 11.328319},
#     'roof': {'latitude': 43.321406, 'longitude': 11.328319}},
#    'link': '/v3/places/5958042f35d3fc2a960473c7',
#    'location': {'address': 'Viale Curtatone 18',
#     'admin_region': 'Toscana',
#     'country': 'IT',
#     'cross_street': 'Via Tozzi',
#     'formatted_address': 'Viale Curtatone 18 (Via Tozzi), 53100 Siena Toscana',
#     'locality': 'Siena',
#     'postcode': '53100',
#     'region': 'Toscana'},
#    'name': 'Pizzeria Alle Scalette',
#    'related_places': {},
#    'timezone': 'Europe/Rome'},
#   {'fsq_id': '4cb0b499562d224b78d31888',
#    'categories': [{'id': 16041,
#      'name': 'Plaza',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/plaza_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'distance': 61,
#    'geocodes': {'main': {'latitude': 43.32121, 'longitude': 11.328699},
#     'roof': {'latitude': 43.32121, 'longitude': 11.328699}},
#    'link': '/v3/places/4cb0b499562d224b78d31888',
#    'location': {'address': 'Piazza Giacomo Matteotti',
#     'admin_region': 'Toscana',
#     'country': 'IT',
#     'cross_street': '',
#     'formatted_address': 'Piazza Giacomo Matteotti, 53100 Siena Toscana',
#     'locality': 'Siena',
#     'postcode': '53100',
#     'region': 'Toscana'},
#    'name': 'Piazza Giacomo Matteotti',
#    'related_places': {},
#    'timezone': 'Europe/Rome'},
#   {'fsq_id': '4bc72a570050b713f41db83b',
#    'categories': [{'id': 12101,
#      'name': 'Church',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/religious_church_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'distance': 156,
#    'geocodes': {'main': {'latitude': 43.31998, 'longitude': 11.326576},
#     'roof': {'latitude': 43.31998, 'longitude': 11.326576}},
#    'link': '/v3/places/4bc72a570050b713f41db83b',
#    'location': {'address': 'Piazza San Domenico',
#     'admin_region': 'Toscana',
#     'country': 'IT',
#     'cross_street': '',
#     'formatted_address': 'Piazza San Domenico, 53100 Siena Toscana',
#     'locality': 'Siena',
#     'postcode': '53100',
#     'region': 'Toscana'},
#    'name': 'Basilica di San Domenico',
#    'related_places': {},
#    'timezone': 'Europe/Rome'},
#   {'fsq_id': '4d22fbc7d7b0b1f754a3299f',
#    'categories': [{'id': 13003,
#      'name': 'Bar',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#       'suffix': '.png'}},
#     {'id': 13034,
#      'name': 'Café',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#       'suffix': '.png'}},
#     {'id': 13236,
#      'name': 'Italian Restaurant',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'distance': 142,
#    'geocodes': {'drop_off': {'latitude': 43.321803, 'longitude': 11.329714},
#     'main': {'latitude': 43.321911, 'longitude': 11.329777},
#     'roof': {'latitude': 43.321911, 'longitude': 11.329777}},
#    'link': '/v3/places/4d22fbc7d7b0b1f754a3299f',
#    'location': {'address': 'Via Montanini 52',
#     'admin_region': 'Toscana',
#     'country': 'IT',
#     'cross_street': '',
#     'formatted_address': 'Via Montanini 52, 53100 Siena Siena',
#     'locality': 'Siena',
#     'postcode': '53100',
#     'region': 'Siena'},
#    'name': 'Caffè La Piazzetta',
#    'related_places': {},
#    'timezone': 'Europe/Rome'},
#   {'fsq_id': '4bdebeb7e75c0f47c699c803',
#    'categories': [{'id': 17069,
#      'name': 'Grocery Store',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_grocery_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'distance': 180,
#    'geocodes': {'main': {'latitude': 43.321098, 'longitude': 11.330164},
#     'roof': {'latitude': 43.321098, 'longitude': 11.330164}},
#    'link': '/v3/places/4bdebeb7e75c0f47c699c803',
#    'location': {'address': 'Via Pianigiani Giuseppe 9',
#     'admin_region': 'Toscana',
#     'country': 'IT',
#     'formatted_address': 'Via Pianigiani Giuseppe 9, 53100 Siena Toscana',
#     'locality': 'Siena',
#     'postcode': '53100',
#     'region': 'Toscana'},
#    'name': 'Consorzio Agrario di Siena',
#    'related_places': {},
#    'timezone': 'Europe/Rome'},
#   {'fsq_id': '4fd7724ee4b07220ec56191e',
#    'categories': [{'id': 13064,
#      'name': 'Pizzeria',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#       'suffix': '.png'}},
#     {'id': 13236,
#      'name': 'Italian Restaurant',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'distance': 156,
#    'geocodes': {'drop_off': {'latitude': 43.32021, 'longitude': 11.327188},
#     'main': {'latitude': 43.320266, 'longitude': 11.32737},
#     'roof': {'latitude': 43.320266, 'longitude': 11.32737}},
#    'link': '/v3/places/4fd7724ee4b07220ec56191e',
#    'location': {'address': 'Via Camporegio 1',
#     'admin_region': 'Toscana',
#     'country': 'IT',
#     'cross_street': '',
#     'formatted_address': 'Via Camporegio 1, 53100 Siena Toscana',
#     'locality': 'Siena',
#     'postcode': '53100',
#     'region': 'Toscana'},
#    'name': 'Il Masgalano',
#    'related_places': {},
#    'timezone': 'Europe/Rome'},
#   {'fsq_id': '4bfac4574a67c928cfb828cf',
#    'categories': [{'id': 13064,
#      'name': 'Pizzeria',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'distance': 162,
#    'geocodes': {'main': {'latitude': 43.320248, 'longitude': 11.327872},
#     'roof': {'latitude': 43.320248, 'longitude': 11.327872}},
#    'link': '/v3/places/4bfac4574a67c928cfb828cf',
#    'location': {'address': 'Via Camporegio 13',
#     'admin_region': 'Toscana',
#     'country': 'IT',
#     'formatted_address': 'Via Camporegio 13, 53100 Siena Toscana',
#     'locality': 'Siena',
#     'postcode': '53100',
#     'region': 'Toscana'},
#    'name': 'Il Pomodorino',
#    'related_places': {},
#    'timezone': 'Europe/Rome'},
#   {'fsq_id': '4c57f9fdcc96c9b68e0f7a2e',
#    'categories': [{'id': 13025,
#      'name': 'Wine Bar',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/winery_',
#       'suffix': '.png'}},
#     {'id': 13032,
#      'name': 'Cafe, Coffee, and Tea House',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#       'suffix': '.png'}},
#     {'id': 13236,
#      'name': 'Italian Restaurant',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'distance': 179,
#    'geocodes': {'drop_off': {'latitude': 43.320189, 'longitude': 11.328824},
#     'main': {'latitude': 43.320146, 'longitude': 11.328744},
#     'roof': {'latitude': 43.320146, 'longitude': 11.328744}},
#    'link': '/v3/places/4c57f9fdcc96c9b68e0f7a2e',
#    'location': {'address': "Costa di Sant'Antonio 13",
#     'admin_region': 'Toscana',
#     'country': 'IT',
#     'cross_street': 'Via dei Pittori',
#     'formatted_address': "Costa di Sant'Antonio 13 (Via dei Pittori), 53100 Siena Toscana",
#     'locality': 'Siena',
#     'postcode': '53100',
#     'region': 'Toscana'},
#    'name': 'Zest Ristorante & Winebar',
#    'related_places': {},
#    'timezone': 'Europe/Rome'},
#   {'fsq_id': '4bcb0813fb84c9b6bc061e3e',
#    'categories': [{'id': 13003,
#      'name': 'Bar',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#       'suffix': '.png'}},
#     {'id': 13034,
#      'name': 'Café',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#       'suffix': '.png'}},
#     {'id': 13065,
#      'name': 'Restaurant',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'distance': 145,
#    'geocodes': {'main': {'latitude': 43.323074, 'longitude': 11.328087},
#     'roof': {'latitude': 43.323074, 'longitude': 11.328087}},
#    'link': '/v3/places/4bcb0813fb84c9b6bc061e3e',
#    'location': {'address': 'Piazza Antonio Gramsci 10',
#     'address_extended': 'A',
#     'admin_region': 'Toscana',
#     'country': 'IT',
#     'cross_street': '',
#     'formatted_address': 'Piazza Antonio Gramsci 10, 53100 Siena Toscana',
#     'locality': 'Siena',
#     'postcode': '53100',
#     'region': 'Toscana'},
#    'name': 'Antico Bar La Lizza',
#    'related_places': {},
#    'timezone': 'Europe/Rome'},
#   {'fsq_id': '4f454052e4b0868b4200f7cd',
#    'categories': [{'id': 13065,
#      'name': 'Restaurant',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'distance': 170,
#    'geocodes': {'drop_off': {'latitude': 43.320109, 'longitude': 11.328259},
#     'main': {'latitude': 43.320223, 'longitude': 11.328283},
#     'roof': {'latitude': 43.320223, 'longitude': 11.328283}},
#    'link': '/v3/places/4f454052e4b0868b4200f7cd',
#    'location': {'address': 'Via Camporegio 17',
#     'admin_region': 'Toscana',
#     'country': 'IT',
#     'cross_street': '',
#     'formatted_address': 'Via Camporegio 17, 53100 Siena Toscana',
#     'locality': 'Siena',
#     'postcode': '53100',
#     'region': 'Toscana'},
#    'name': 'Ristorante San Domenico',
#    'related_places': {},
#    'timezone': 'Europe/Rome'}],
#  'context': {'geo_bounds': {'circle': {'center': {'latitude': 43.3216,
#      'longitude': 11.327948},
#     'radius': 1000}}}}

# %% [markdown]
# Parse through the response to get the POI (such as restaurants, bars, etc) details you want (ratings, name, location, etc)

# %%
res_lst = []
for res_json in res_json_lst:
    result = res_json['results']
    for i in range(len(result)):
        dict = {}
        dict['name'] = result[i]['name']
        dict['address'] = result[i]['location']['address']
        if result[i]['categories']:
            dict['category'] = result[i]['categories'][0]['name']
        res_lst.append(dict)

res_lst
# Out:
# [{'name': 'Pizzeria Alle Scalette',
#   'address': 'Viale Curtatone 18',
#   'category': 'Pizzeria'},
#  {'name': 'Piazza Giacomo Matteotti',
#   'address': 'Piazza Giacomo Matteotti',
#   'category': 'Plaza'},
#  {'name': 'Basilica di San Domenico',
#   'address': 'Piazza San Domenico',
#   'category': 'Church'},
#  {'name': 'Caffè La Piazzetta',
#   'address': 'Via Montanini 52',
#   'category': 'Bar'},
#  {'name': 'Consorzio Agrario di Siena',
#   'address': 'Via Pianigiani Giuseppe 9',
#   'category': 'Grocery Store'},
#  {'name': 'Il Masgalano',
#   'address': 'Via Camporegio 1',
#   'category': 'Pizzeria'},
#  {'name': 'Il Pomodorino',
#   'address': 'Via Camporegio 13',
#   'category': 'Pizzeria'},
#  {'name': 'Zest Ristorante & Winebar',
#   'address': "Costa di Sant'Antonio 13",
#   'category': 'Wine Bar'},
#  {'name': 'Antico Bar La Lizza',
#   'address': 'Piazza Antonio Gramsci 10',
#   'category': 'Bar'},
#  {'name': 'Ristorante San Domenico',
#   'address': 'Via Camporegio 17',
#   'category': 'Restaurant'},
#  {'name': 'La Taverna di San Giuseppe',
#   'address': 'Via Giovanni Duprè 132',
#   'category': 'Tuscan Restaurant'},
#  {'name': 'Osteria Castelvecchio',
#   'address': 'Via Castelvecchio 65',
#   'category': 'Pizzeria'},
#  {'name': 'Osteria da Cice',
#   'address': 'Via San Pietro 32',
#   'category': 'Italian Restaurant'},
#  {'name': 'La Vecchia Latteria',
#   'address': 'Via San Pietro 10',
#   'category': 'Ice Cream Parlor'},
#  {'name': "Mensa Sant'Agata",
#   'address': "Via Sant'Agata 1",
#   'category': 'Café'},
#  {'name': 'Hotel Duomo SRL',
#   'address': 'Via Stalloreggi 38',
#   'category': 'Hotel'},
#  {'name': 'Pinacotaca Nazionale di Siena',
#   'address': 'Via di San Pietro 29',
#   'category': 'Museum'},
#  {'name': 'La Taverna Del Capitano',
#   'address': 'Via del Capitano 6',
#   'category': 'Pizzeria'},
#  {'name': 'Boccon del Prete',
#   'address': 'Via di San Pietro 17',
#   'category': 'Trattoria'},
#  {'name': 'Permalico Vini e Merende SNC di Mattii e Mottola',
#   'address': 'Costa Larga 4',
#   'category': 'Bar'},
#  {'name': 'Gelateria Nice',
#   'address': 'Via di Pantaneto 152',
#   'category': 'Ice Cream Parlor'},
#  {'name': 'Osteria La Sosta di Violante',
#   'address': 'Via di Pantaneto 115',
#   'category': 'Trattoria'},
#  {'name': 'Da Gano', 'address': 'Via Pantaneto 146', 'category': 'Trattoria'},
#  {'name': 'Supermercati Conad',
#   'address': 'Via Pantaneto',
#   'category': 'Grocery Store'},
#  {'name': 'Bella Vista Social Pub',
#   'address': 'Via di pantaneto',
#   'category': 'Arts and Entertainment'},
#  {'name': 'La Prosciutteria',
#   'address': 'Via di Pantaneto 89',
#   'category': 'Bar'},
#  {'name': 'Meet Life Café', 'address': 'Via Pantaneto 90', 'category': 'Bar'},
#  {'name': 'Porta Romana',
#   'address': 'Via Roma',
#   'category': 'Other Great Outdoors'},
#  {'name': 'Grotta Gallo Nero',
#   'address': 'Via Porrione 65',
#   'category': 'Italian Restaurant'},
#  {'name': 'Gallo Nero',
#   'address': 'Via del Porrione 65',
#   'category': 'Italian Restaurant'},
#  {'name': 'Fortezza Medicea',
#   'address': 'Piazza Caduti delle Forze Armate',
#   'category': 'Landmarks and Outdoors'},
#  {'name': 'Osteria del Buon Governo',
#   'address': 'Viale Vittorio Veneto 29',
#   'category': 'Diner'},
#  {'name': 'Basilica di San Domenico',
#   'address': 'Piazza San Domenico',
#   'category': 'Church'},
#  {'name': 'Fondazione Siena Jazz - Accademia Nazionale del Jazz',
#   'address': "Piazza Caduti delle Forze dell'Ordine",
#   'category': 'Music School'},
#  {'name': 'Il Masgalano',
#   'address': 'Via Camporegio 1',
#   'category': 'Pizzeria'},
#  {'name': 'Blandis Cafè & Wine Bar',
#   'address': 'Via Esterna di Fontebranda 50-52',
#   'category': 'Bar'},
#  {'name': 'Fontebranda',
#   'address': 'Via di Fontebranda',
#   'category': 'Monument'},
#  {'name': 'Osteria Enoteca Sotto Le Fonti',
#   'address': 'Via Esterna di Fontebranda 114',
#   'category': 'Trattoria'},
#  {'name': 'Il Pomodorino',
#   'address': 'Via Camporegio 13',
#   'category': 'Pizzeria'},
#  {'name': 'Ristorante San Domenico',
#   'address': 'Via Camporegio 17',
#   'category': 'Restaurant'},
#  {'name': 'Antiporto di Camollia',
#   'address': 'Via Vittorio Emanuele II',
#   'category': 'Historic and Protected Site'},
#  {'name': 'Ravioli Wang',
#   'address': 'Viale Vittorio Emanuele II 38',
#   'category': 'Chinese Restaurant'},
#  {'name': 'Gelateria Il Bacio',
#   'address': 'Via Vittorio Emanuele II 55',
#   'category': 'Ice Cream Parlor'},
#  {'name': 'Turkish Pace Kebap',
#   'address': 'Viale Cavour',
#   'category': 'Turkish Restaurant'},
#  {'name': 'Snack Bar 1961',
#   'address': 'Viale Vittorio Emanuele II 64',
#   'category': 'Café'},
#  {'name': 'Vodafone Store',
#   'address': 'Corso Cavour 2',
#   'category': 'Mobile Phone Store'},
#  {'name': 'Bar Impero Siena',
#   'address': 'Viale Vittorio Emanuele II 10',
#   'category': 'Cocktail Bar'},
#  {'name': 'Sushiko',
#   'address': 'Piazzale Carlo Rosselli 25',
#   'category': 'Sushi Restaurant'},
#  {'name': 'Pub Pizzeria La Risalita',
#   'address': 'Via Vittorio Emanuele 57',
#   'category': 'Pizzeria'},
#  {'name': 'Solo Affitti - Siena',
#   'address': 'Viale Vittorio Emanuele II',
#   'category': 'Real Estate Agency'},
#  {'name': 'Burger King',
#   'address': 'Viale Toselli',
#   'category': 'Burger Joint'},
#  {'name': 'Simply viale Toselli',
#   'address': 'Piazza Maestri del Lavori',
#   'category': 'Department Store'},
#  {'name': 'Prosalus Sanitaria',
#   'address': 'Viale Pietro Toselli 21',
#   'category': 'Medical Supply Store'},
#  {'name': 'Donna Ripalta',
#   'address': 'Viale Pietro Toselli 41',
#   'category': 'BBQ Joint'},
#  {'name': 'Acquedotto del Fiora',
#   'address': 'Viale Pietro Toselli 9',
#   'category': 'Food and Beverage Service'},
#  {'name': 'Penny Market',
#   'address': 'Via Toselli 11',
#   'category': 'Dining and Drinking'},
#  {'name': 'Rakki Sushi Siena',
#   'address': 'Piazza Maestri del Lavoro 31',
#   'category': 'Sushi Restaurant'},
#  {'name': 'Vodafone Store',
#   'address': 'Via Toselli 116',
#   'category': 'Mobile Phone Store'},
#  {'name': 'Ricoh Italia SRL', 'address': 'Viale Toselli Pietro 11'},
#  {'name': 'Terrecablate Reti e Servizi SRL',
#   'address': 'Viale Pietro Toselli 9'},
#  {'name': 'Fontebecci',
#   'address': 'Via Fiorentina 133',
#   'category': 'Pizzeria'},
#  {'name': 'Bruzzese Tuttoparquet',
#   'address': 'Via Fiorentina 112',
#   'category': 'Carpet and Flooring Contractor'},
#  {'name': 'Creme Gelateria Dolceria',
#   'address': 'Via Fiorentina 151',
#   'category': 'Cupcake Shop'},
#  {'name': 'Pizzeria Poppi',
#   'address': 'Via Fiorentina 105',
#   'category': 'Pizzeria'},
#  {'name': 'Al Fiumino',
#   'address': 'Via Giovanni Paolo II',
#   'category': 'Wine Bar'},
#  {'name': "McDonald's",
#   'address': 'Via Fiorentina 122',
#   'category': 'Burger Joint'},
#  {'name': "Centro Per L'impiego", 'address': 'Via Fiorentina 91'},
#  {'name': 'Pizzeria La Fenice',
#   'address': 'Via Fiorentina 88',
#   'category': 'Pizzeria'},
#  {'name': 'Ristorante Il Mestolo',
#   'address': 'Via Fiorentina 81',
#   'category': 'Italian Restaurant'},
#  {'name': 'Secar 2009',
#   'address': 'Via Fiorentina 116',
#   'category': 'Automotive Repair Shop'},
#  {'name': 'Associazione Coccinelle - Amici del neonato',
#   'address': 'Viale Bracci 16'},
#  {'name': 'Ospedali Riuniti',
#   'address': 'Viale Mario Bracci 16',
#   'category': 'Hospital'},
#  {'name': 'Azienda U.S.L. 7 di Siena',
#   'address': 'Viale Bracci Mario 16',
#   'category': 'Health and Medicine'},
#  {'name': 'Azienda Ospedaliera Senese',
#   'address': 'Viale Bracci Mario 16',
#   'category': 'Hospital'},
#  {'name': 'Pizzeria Tavola Calda Bracci', 'address': 'Viale Bracci 4'},
#  {'name': 'A.O. Universitaria Senese', 'address': 'Viale M. Bracci 16'},
#  {'name': 'Mensa San Miniato Ristorante',
#   'address': 'Via de Nicola 9',
#   'category': 'Restaurant'},
#  {'name': 'Associazione Toscana Leucemie Onlus',
#   'address': 'Viale Bracci Mario 16',
#   'category': 'Community and Government'},
#  {'name': 'Patologia Orale', 'address': 'Viale Bracci'},
#  {'name': 'Dr Maurizio Biagioli',
#   'address': 'Viale Bracci 16',
#   'category': 'Dermatologist'},
#  {'name': 'Poste Italiane',
#   'address': 'Via Savina Petrilli 2',
#   'category': 'Post Office'},
#  {'name': 'Pizzeria La Strana Coppia',
#   'address': 'Via Celso Cittadini 6',
#   'category': 'Pizzeria'},
#  {'name': 'CUS Siena',
#   'address': 'Via Luciano Banchi 3',
#   'category': 'Gym and Studio'},
#  {'name': 'Bar Giglio', 'address': 'Via Colombini 32', 'category': 'Bar'},
#  {'name': 'Centro Servizi Familiari di Tavaglione M.& C. SNC',
#   'address': 'Via B. Tolomei 10',
#   'category': 'Metals Supplier'},
#  {'name': 'Palacorsoni Siena',
#   'address': 'Via L. Banchi 5',
#   'category': 'Stadium'},
#  {'name': 'Ufficio Anagrafe e Stato Civile',
#   'address': 'Via Bernardo Tolomei 7',
#   'category': 'Community and Government'},
#  {'name': 'Parco Bernardino Ochino',
#   'address': 'Via Luciano Banchi',
#   'category': 'Sports and Recreation'},
#  {'name': 'San Gonnario Beer Shop',
#   'address': 'Via Colombini 42',
#   'category': 'Beer Store'},
#  {'name': 'Laboratorio Odontotecnico Senese di Boldrini Mario e C. - SNC',
#   'address': 'Via Savina Petrilli 17',
#   'category': 'Medical Center'},
#  {'name': 'La Grotta di San Francesco',
#   'address': 'Via Baldassarre Peruzzi 20',
#   'category': 'Pizzeria'},
#  {'name': 'Particolare di Siena',
#   'address': 'Via Baldassarre Peruzzi 26',
#   'category': 'Restaurant'},
#  {'name': "Osteria L'Osteria",
#   'address': 'Via dei Rossi 79',
#   'category': 'Italian Restaurant'},
#  {'name': 'Tre Cristi',
#   'address': 'Vicolo di Provenzano 1',
#   'category': 'Italian Restaurant'},
#  {'name': "L'oro di Siena di Luppoli Marcellino & C. SNC",
#   'address': 'Via Giuseppe Garibaldi 61',
#   'category': 'Pizzeria'},
#  {'name': 'Osteria Le Sorelline',
#   'address': 'Via dei Rossi 76',
#   'category': 'Restaurant'},
#  {'name': 'Campetto da Basket di Ravacciano',
#   'address': 'Via del Vecchietta',
#   'category': 'Basketball Court'},
#  {'name': 'Sushi Bar',
#   'address': 'Via Domenico Beccafumi 10',
#   'category': 'Trattoria'},
#  {'name': 'Piazza Salimbeni',
#   'address': 'Piazza Salimbeni',
#   'category': 'Historic and Protected Site'},
#  {'name': 'La Prosciutteria',
#   'address': 'Via di Pantaneto 89',
#   'category': 'Bar'},
#  {'name': 'La Pizzeria di San Miniato',
#   'address': 'Piazza Palmiro Togliatti 2',
#   'category': 'Pizzeria'},
#  {'name': 'Scaccini e Cucini di Scaccini S. e Cucini M SNC',
#   'address': 'Piazza Palmiro Togliatti 3',
#   'category': 'Bar'},
#  {'name': 'Forno San Miniato',
#   'address': 'Piazza Togliatti 7',
#   'category': 'Wholesaler'},
#  {'name': 'Cooperativa San Miniato',
#   'address': 'Piazza Palmiro Togliatti',
#   'category': 'Convenience Store'},
#  {'name': 'Si Donna',
#   'address': 'Piazza Palmiro Togliatti 15',
#   'category': 'Business and Professional Services'},
#  {'name': 'Cittinilandia', 'address': 'Via Achille Grandi 2'},
#  {'name': 'Farmacia Laguardia',
#   'address': 'Via Grandi 2',
#   'category': 'Drugstore'},
#  {'name': 'Simus - Museo Anatomico Leonetto Comparini',
#   'address': 'Via Aldo Moro 2',
#   'category': 'Science Museum'},
#  {'name': 'Circolo Acli San Miniato',
#   'address': 'Via Aldo Moro 4',
#   'category': 'Organization'},
#  {'name': 'Mps Leasing & Factoring SPA',
#   'address': 'Via Aldo Moro 11',
#   'category': 'Loans Agency'},
#  {'name': 'Sushiko',
#   'address': 'Piazzale Carlo Rosselli 25',
#   'category': 'Sushi Restaurant'},
#  {'name': 'Punto Enel',
#   'address': 'Via Lauro de Bosis 26',
#   'category': 'Miscellaneous Store'},
#  {'name': 'Chianti Banca',
#   'address': 'Via Lauro de Bosis 20',
#   'category': 'Bank'},
#  {'name': 'GameStop', 'address': 'Piazzale Carlo Rosselli 22'},
#  {'name': 'Farmacia Comunale',
#   'address': 'Stazione Ferroviaria di Siena, Piazzale Carlo Rosselli',
#   'category': 'Drugstore'},
#  {'name': 'Ristorante Primo Binario',
#   'address': 'Piazza Carlo Rosselli 19',
#   'category': 'Pizzeria'},
#  {'name': 'Bar Ristorante Stazione',
#   'address': 'Piazza Rosselli Carlo 6',
#   'category': 'Bar'},
#  {'name': 'Colours & Beauty',
#   'address': 'Piazzale carlo rosselli 25',
#   'category': 'Fashion Retail'},
#  {'name': 'Cibiamo - La Bottega del Caffè',
#   'address': 'Piazza Carlo Rosselli 22',
#   'category': 'Coffee Shop'},
#  {'name': 'Centro Commerciale Porta Siena',
#   'address': 'Piazza Carlo Rosselli 25',
#   'category': 'Shopping Mall'},
#  {'name': 'La Veranda',
#   'address': 'Piazza Calabria 20',
#   'category': 'Pizzeria'},
#  {'name': 'Skilè Music Bar',
#   'address': 'Piazza Calabria 18',
#   'category': 'Arts and Entertainment'},
#  {'name': 'Pasticceria Senese',
#   'address': 'piazza Calabria 25',
#   'category': 'Dessert Shop'},
#  {'name': 'Al Fiumino',
#   'address': 'Via Giovanni Paolo II',
#   'category': 'Wine Bar'},
#  {'name': 'Motorizzazione Civile',
#   'address': 'Via delle Regioni 70',
#   'category': 'Government Building'},
#  {'name': 'Agenzia Del Territorio',
#   'address': 'Via Liguria 4',
#   'category': 'Community and Government'},
#  {'name': 'Studio Commerciale Associato Turillazzi',
#   'address': 'Via Liguria 19',
#   'category': 'Business and Strategy Consulting Office'},
#  {'name': 'Skilè Music Pub',
#   'address': 'Piazza Calabria 18-19',
#   'category': 'Food and Beverage Retail'},
#  {'name': 'Il Salottino di Moira', 'address': 'Piazza Calabria 16'},
#  {'name': "Emporio Dell'Usato di Fantacci Luca e C.",
#   'address': 'Via delle Regioni 23',
#   'category': 'Vintage and Thrift Store'},
#  {'name': "L'oro di Siena di Luppoli Marcellino & C. SNC",
#   'address': 'Via Giuseppe Garibaldi 61',
#   'category': 'Pizzeria'},
#  {'name': 'Sushi Bar',
#   'address': 'Via Domenico Beccafumi 10',
#   'category': 'Trattoria'},
#  {'name': 'Poste Italiane',
#   'address': 'Viale Giuseppe Mazzini 6',
#   'category': 'Post Office'},
#  {'name': 'Bar Beccafumi SNC',
#   'address': 'Via Beccafumi 2',
#   'category': 'Bar'},
#  {'name': "Osteria L'Osteria",
#   'address': 'Via dei Rossi 79',
#   'category': 'Italian Restaurant'},
#  {'name': 'Osteria di Kamollia',
#   'address': 'Via Camollia 114',
#   'category': 'Trattoria'},
#  {'name': 'Osteria Il Vinaio',
#   'address': 'Via Camollia 167',
#   'category': 'Deli'},
#  {'name': 'Enzo', 'address': 'Via Camollia 49'},
#  {'name': 'Bepharma',
#   'address': 'Via Simone Martini 25',
#   'category': 'Drugstore'},
#  {'name': 'Trattoria Fonte Giusta',
#   'address': 'Via Camollia 102',
#   'category': 'Trattoria'},
#  {'name': 'Mercato di Campagna Amica',
#   'address': 'Via Paolo Frajese 21',
#   'category': 'Farmers Market'},
#  {'name': 'Enzo Sushi',
#   'address': 'Via Paolo Frajese 63',
#   'category': 'Restaurant'},
#  {'name': 'Pista Engels Lambardi',
#   'address': 'Strada di Pescaia 121a',
#   'category': 'Hockey Field'},
#  {'name': 'Cannoleria Ke Cassata', 'address': 'Strada di Pescaia 117'},
#  {'name': 'Il Tagliere di Lele',
#   'address': 'Strada Pescaia 129',
#   'category': 'Bar'},
#  {'name': 'La Gelateria del 103',
#   'address': 'Strada di Pescaia 125',
#   'category': 'Pastry Shop'},
#  {'name': 'Art Pizza e Bar al 103',
#   'address': 'Strada di Pescaia 103',
#   'category': 'Pizzeria'},
#  {'name': 'Da Michele',
#   'address': 'Strada Massetana 64',
#   'category': 'Pizzeria'},
#  {'name': 'Carrefour Express',
#   'address': 'Via di Pescaia 97',
#   'category': 'Grocery Store'},
#  {'name': 'Podere Il Pero',
#   'address': 'Strada Montalbuccio 29',
#   'category': 'Bed and Breakfast'},
#  {'name': 'Tea-Room Porta Giustizia',
#   'address': 'Via di Porta Giustizia 11',
#   'category': 'Bar'},
#  {'name': 'Ristorante La Finestra',
#   'address': 'Piazza Mercato 14',
#   'category': 'Diner'},
#  {'name': 'Gino Cacino',
#   'address': 'Piazza del Mercato 31',
#   'category': 'Food and Beverage Retail'},
#  {'name': 'Piazza del Mercato',
#   'address': 'Piazza del Mercato',
#   'category': 'Plaza'},
#  {'name': 'Grotta Gallo Nero',
#   'address': 'Via Porrione 65',
#   'category': 'Italian Restaurant'},
#  {'name': 'Trattoria Papei',
#   'address': 'Piazza del Mercato 6',
#   'category': 'Trattoria'},
#  {'name': 'Maudit Pub',
#   'address': 'Vicolo della Fortuna 21',
#   'category': 'Dive Bar'},
#  {'name': 'Palazzo Pubblico',
#   'address': 'Piazza del Campo 1',
#   'category': 'Historic and Protected Site'},
#  {'name': 'Gallo Nero',
#   'address': 'Via del Porrione 65',
#   'category': 'Italian Restaurant'},
#  {'name': 'Torre Del Mangia',
#   'address': 'Piazza del Campo',
#   'category': 'Monument'},
#  {'name': 'Bed & Breakfast Fonte dei Tufi',
#   'address': 'Strada dei Tufi 59',
#   'category': 'Bed and Breakfast'},
#  {'name': 'Emporio Musicale Senese',
#   'address': 'Strada di Cerchiaia 11',
#   'category': 'Music Store'},
#  {'name': 'La Stramba',
#   'address': 'Strada dei Tufi 66',
#   'category': 'Vacation Rental'},
#  {'name': 'M&Mj SRL Semplificata', 'address': 'Strada dei Tufi 66'},
#  {'name': 'Costa Del Sole SRL', 'address': 'Strada dei Tufi 61'},
#  {'name': 'Euronics',
#   'address': 'Strada Massetana Romana 62',
#   'category': 'Electronics Store'},
#  {'name': 'Edilsiena SRL', 'address': 'Via Piccolomini Enea Silvio 185'},
#  {'name': 'Villa Il Borghetto', 'address': 'Via Tufi no. 64'},
#  {'name': 'Il Palazzetto',
#   'address': 'Strada del Lucherino 31',
#   'category': 'Hotel'},
#  {'name': 'Studio Etruria di p.a. Megna',
#   'address': 'Via Enea Silvio Piccolomini 199'},
#  {'name': 'Mensa San Miniato Ristorante',
#   'address': 'Via de Nicola 9',
#   'category': 'Restaurant'},
#  {'name': 'Pepi Luca',
#   'address': 'Via de Nicola Enrico 3',
#   'category': 'Upholstery Service'},
#  {'name': 'Ditta B.F.M. di Bartali Fabrizio',
#   'address': 'Via Buozzi 65',
#   'category': 'Metals Supplier'},
#  {'name': 'Mini Rolando',
#   'address': 'Via Enrico Berlinguer 19',
#   'category': 'Painter'},
#  {'name': 'Vivenda SPA', 'address': 'Via Aldo Moro 2'},
#  {'name': 'Tempio Israelitico',
#   'address': 'Via delle Scotte',
#   'category': 'Synagogue'},
#  {'name': 'Bartalini Mario',
#   'address': 'Via de Gasperi Alcide 2',
#   'category': 'Home Improvement Service'},
#  {'name': 'Cooperativa San Miniato',
#   'address': 'Piazza Palmiro Togliatti',
#   'category': 'Convenience Store'},
#  {'name': 'Butini Arch. Riccardo',
#   'address': 'Via Lizzadri Oreste 27',
#   'category': 'Business and Professional Services'},
#  {'name': 'G.v Impianti Elettrici di Valenti Gianni',
#   'address': 'Via Alcide de Gasperi 6',
#   'category': 'Electrician'},
#  {'name': 'Pasticceria Pierini',
#   'address': 'Via Quinto Settano 5',
#   'category': 'Bakery'},
#  {'name': 'Zelig Sociale Società Cooperativa Sociale A R. L.',
#   'address': 'Strada del Petriccio 49'},
#  {'name': 'San Gonnario Beer Shop',
#   'address': 'Via Colombini 42',
#   'category': 'Beer Store'},
#  {'name': 'Centro Diagnostico Senese',
#   'address': 'Via Cittadini 7',
#   'category': 'Healthcare Clinic'},
#  {'name': 'Erboristeria La Pimpinella',
#   'address': 'Via Celso Cittadini 16',
#   'category': 'Alternative Medicine Clinic'},
#  {'name': 'Parrocchia Beato Bernardo Tolomei',
#   'address': 'Via Tolomei Bernardo 1',
#   'category': 'Church'},
#  {'name': 'Dr. Vigni Farmacia',
#   'address': 'Via Quinto Settano 1',
#   'category': 'Drugstore'},
#  {'name': 'Poste Italiane',
#   'address': 'Via Savina Petrilli 2',
#   'category': 'Post Office'},
#  {'name': 'Bar Giglio', 'address': 'Via Colombini 32', 'category': 'Bar'},
#  {'name': 'Bovicelli Roberto',
#   'address': 'Via Gallerani 23',
#   'category': 'Dentist'}]

# %% [markdown]
# Put your parsed results into a DataFrame

# %%
df_foursquare = pd.DataFrame(res_lst)
df_foursquare
# Out:
#                                   name                    address  \
# 0               Pizzeria Alle Scalette         Viale Curtatone 18
# 1             Piazza Giacomo Matteotti   Piazza Giacomo Matteotti
# 2             Basilica di San Domenico        Piazza San Domenico
# 3                   Caffè La Piazzetta           Via Montanini 52
# 4           Consorzio Agrario di Siena  Via Pianigiani Giuseppe 9
# ..                                 ...                        ...
# 185  Parrocchia Beato Bernardo Tolomei     Via Tolomei Bernardo 1
# 186                 Dr. Vigni Farmacia       Via Quinto Settano 1
# 187                     Poste Italiane      Via Savina Petrilli 2
# 188                         Bar Giglio           Via Colombini 32
# 189                  Bovicelli Roberto           Via Gallerani 23
#
#           category
# 0         Pizzeria
# 1            Plaza
# 2           Church
# 3              Bar
# 4    Grocery Store
# ..             ...
# 185         Church
# 186      Drugstore
# 187    Post Office
# 188            Bar
# 189        Dentist
#
# [190 rows x 3 columns]

# %% [markdown]
# # Yelp

# %% [markdown]
# Send a request to Yelp with a small radius (1000m) for all the bike stations in your city of choice.

# %%
yelp_params_lst = [{
    'latitude' : '43.321600',
    'longitude' : '11.327948',
    'radius': '1000'
},
{
    'latitude' : '43.314554',
    'longitude': '11.331021',
    'radius': '1000'
},
{
    'latitude' : '43.316539',
    'longitude': '11.337212',
    'radius': '1000'
},
{
    'latitude' : '43.320523',
    'longitude': '11.323225',
    'radius': '1000'
},
{
    'latitude' : '43.328983',
    'longitude': '11.321913',
    'radius': '1000'
},
{
    'latitude' : '43.317187',
    'longitude': '11.354256',
    'radius': '1000'
},
{
    'latitude' : '43.341757',
    'longitude': '11.305010',
    'radius': '1000'
},
{
    'latitude' : '43.343243',
    'longitude': '11.326733',
    'radius': '1000'
},
{
    'latitude' : '43.336999',
    'longitude': '11.300975',
    'radius': '1000'
},
{
    'latitude' : '43.323781',
    'longitude': '11.338891',
    'radius': '1000'
},
{
    'latitude' : '43.347800',
    'longitude': '11.326046',
    'radius': '1000'
},
{
    'latitude' : '43.332288',
    'longitude': '11.324176',
    'radius': '1000'
},
{
    'latitude' : '43.341445',
    'longitude': '11.312348',
    'radius': '1000'
},
{
    'latitude' : '43.326764',
    'longitude': '11.333702',
    'radius': '1000'
},
{
    'latitude' : '43.309896',
    'longitude': '11.315263',
    'radius': '1000'
},
{
    'latitude' : '43.317315',
    'longitude': '11.332998',
    'radius': '1000'
},
{
    'latitude' : '43.296856',
    'longitude': '11.334854',
    'radius': '1000'
},
{
    'latitude' : '43.343407',
    'longitude': '11.322849',
    'radius': '1000'
},
{
    'latitude' : '43.334640',
    'longitude': '11.304803',
    'radius': '1000'
}]

yelp_api_key = os.environ["YELP_API_KEY"]


yelp_url = "https://api.yelp.com/v3/businesses/search"


# headers = {
#   'Authorization': 'Bearer 7YecQFdZ8AtZibuTvODcWT6NQL2TCyh71cGZ-DbQjHkBbahj-qzC7p7WKcTw3EErXTNIfunMklRQmxzJnV9wAbwuL_Hv0yybKzXjcgMOMvBx89_Rqlncj6i4cKbEZHYx'
# }

yelp_api_key = 'Bearer %s' %yelp_api_key

headers = {
  'Authorization': yelp_api_key
}

params = {
    "latitude": 43.321600,
    "longitude": 11.327948,
    "radius": 1000
}

headers
payload = {}

# response = requests.request('GET', yelp_url, params=params, headers=headers, data=payload)
# res_json = response.json()

# res_json = res_json['businesses']
# res_json[0]['name']

yelp_res_json_lst = []
for params in yelp_params_lst:
    yelp_response = requests.get(yelp_url, params=params, headers=headers)
    yelp_res_json = yelp_response.json()
    yelp_res_json_lst.append(yelp_res_json)

yelp_res_json_lst[0]



# yelp_res_lst = []
# for yelp_res_json in yelp_res_json_lst:
#     yelp_result = yelp_res_json['businesses']
#     for i in range(len(yelp_result)):
#         dict = {}
#         dict['name'] = yelp_result[i]['name']
#         dict['address'] = yelp_result[i]['location']['address']
#         if yelp_result[i]['categories']:
#             dict['category'] = yelp_result[i]['categories'][0]['name']
#         yelp_res_lst.append(dict)

# yelp_res_lst
# Out:
# {'businesses': [{'id': 'TVssrfMd24fCSCsSq5JgFw',
#    'alias': 'la-taverna-di-san-giuseppe-siena-2',
#    'name': 'La Taverna di San Giuseppe',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/7-1SnE0SeFFitvoFDc2aeQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/la-taverna-di-san-giuseppe-siena-2?adjust_creative=0k5_VJSyIM2A1YDO2o8Iyw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=0k5_VJSyIM2A1YDO2o8Iyw',
#    'review_count': 159,
#    'categories': [{'alias': 'tuscan', 'title': 'Tuscan'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 43.3154774, 'longitude': 11.3317009},
#    'transactions': [],
#    'price': '€€€',
#    'location': {'address1': 'Via Giovanni Dupre 132',
#     'address2': '',
#     'address3': '',
#     'city': 'Siena',
#     'zip_code': '53100',
#     'country': 'IT',
#     'state': 'SI',
#     'display_address': ['Via Giovanni Dupre 132', '53100 Siena', 'Italy']},
#    'phone': '+39057742286',
#    'display_phone': '+39 0577 42286',
#    'distance': 745.4320305340132},
#   {'id': 'CrNpb_5a_g5Pq0I-zSptMw',
#    'alias': 'zest-siena',
#    'name': 'Zest',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/Ys6OGTalDdXwPrqBsJxXpA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/zest-siena?adjust_creative=0k5_VJSyIM2A1YDO2o8Iyw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=0k5_VJSyIM2A1YDO2o8Iyw',
#    'review_count': 25,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 43.3201485, 'longitude': 11.3288725},
#    'transactions': [],
#    'price': '€€',
#    'location': {'address1': "Costa di Sant'antonio 13",
#     'address2': '',
#     'address3': '',
#     'city': 'Siena',
#     'zip_code': '53100',
#     'country': 'IT',
#     'state': 'SI',
#     'display_address': ["Costa di Sant'antonio 13", '53100 Siena', 'Italy']},
#    'phone': '+39057757139',
#    'display_phone': '+39 0577 57139',
#    'distance': 177.88513954148152},
#   {'id': 'zOgyopHtVdaFbN2xq5UUEQ',
#    'alias': 'la-chiacchiera-siena',
#    'name': 'La Chiacchiera',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/EVXfHVHIE9lzW3Dd9KZSuQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/la-chiacchiera-siena?adjust_creative=0k5_VJSyIM2A1YDO2o8Iyw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=0k5_VJSyIM2A1YDO2o8Iyw',
#    'review_count': 22,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 43.320128, 'longitude': 11.32891},
#    'transactions': [],
#    'price': '€€',
#    'location': {'address1': 'Via Costa di San Antonio 4',
#     'address2': None,
#     'address3': None,
#     'city': 'Siena',
#     'zip_code': '53100',
#     'country': 'IT',
#     'state': 'SI',
#     'display_address': ['Via Costa di San Antonio 4', '53100 Siena', 'Italy']},
#    'phone': '+390577280631',
#    'display_phone': '+39 0577 280631',
#    'distance': 181.23770420691767},
#   {'id': 'mEc8bjxZj_h8uB_QtkaKVQ',
#    'alias': 'café-nannini-siena',
#    'name': 'Café Nannini',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/uW9LHUakHuRUuEmyRWEx6w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/caf%C3%A9-nannini-siena?adjust_creative=0k5_VJSyIM2A1YDO2o8Iyw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=0k5_VJSyIM2A1YDO2o8Iyw',
#    'review_count': 14,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 43.3218460083008,
#     'longitude': 11.3286447525024},
#    'transactions': [],
#    'price': '€€',
#    'location': {'address1': 'Piazza Matteotti 32',
#     'address2': '',
#     'address3': '',
#     'city': 'Siena',
#     'zip_code': '53100',
#     'country': 'IT',
#     'state': 'SI',
#     'display_address': ['Piazza Matteotti 32', '53100 Siena', 'Italy']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 60.45200063980524},
#   {'id': 'bDfvVfYF5RlQHmodD6wa0g',
#    'alias': 'compagnia-dei-vinattieri-siena',
#    'name': 'Compagnia dei Vinattieri',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/GU78BCBMwZ6pdlP4GdT4Kg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/compagnia-dei-vinattieri-siena?adjust_creative=0k5_VJSyIM2A1YDO2o8Iyw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=0k5_VJSyIM2A1YDO2o8Iyw',
#    'review_count': 22,
#    'categories': [{'alias': 'tuscan', 'title': 'Tuscan'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 43.32029, 'longitude': 11.33014},
#    'transactions': [],
#    'price': '€€€',
#    'location': {'address1': 'Via delle Terme, 79',
#     'address2': None,
#     'address3': None,
#     'city': 'Siena',
#     'zip_code': '53100',
#     'country': 'IT',
#     'state': 'SI',
#     'display_address': ['Via delle Terme, 79', '53100 Siena', 'Italy']},
#    'phone': '+390577236568',
#    'display_phone': '+39 0577 236568',
#    'distance': 231.88015608847434},
#   {'id': '8hvqDKdBPUiYcEwonPCpkQ',
#    'alias': 'salefino-vino-e-cucina-siena',
#    'name': 'Salefino Vino e Cucina',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/CjgjqeP-AC0lUmQ4nLhCyw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/salefino-vino-e-cucina-siena?adjust_creative=0k5_VJSyIM2A1YDO2o8Iyw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=0k5_VJSyIM2A1YDO2o8Iyw',
#    'review_count': 11,
#    'categories': [{'alias': 'tuscan', 'title': 'Tuscan'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 43.3242199, 'longitude': 11.32827},
#    'transactions': [],
#    'price': '€€€',
#    'location': {'address1': 'Via degli Umiliati 1',
#     'address2': '',
#     'address3': '',
#     'city': 'Siena',
#     'zip_code': '53100',
#     'country': 'IT',
#     'state': 'SI',
#     'display_address': ['Via degli Umiliati 1', '53100 Siena', 'Italy']},
#    'phone': '+390577287224',
#    'display_phone': '+39 0577 287224',
#    'distance': 298.4506622965859},
#   {'id': 'jqQNnaFW_GusnIfr--d_dw',
#    'alias': 'pizzeria-alle-scalette-siena',
#    'name': 'Pizzeria alle Scalette',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/7Wb_JJ2BqMVufmtfR3Asng/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/pizzeria-alle-scalette-siena?adjust_creative=0k5_VJSyIM2A1YDO2o8Iyw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=0k5_VJSyIM2A1YDO2o8Iyw',
#    'review_count': 5,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 43.3213609, 'longitude': 11.3279741},
#    'transactions': [],
#    'location': {'address1': 'Viale Curtatone 18',
#     'address2': None,
#     'address3': '',
#     'city': 'Siena',
#     'zip_code': '53100',
#     'country': 'IT',
#     'state': 'SI',
#     'display_address': ['Viale Curtatone 18', '53100 Siena', 'Italy']},
#    'phone': '+3905771522339',
#    'display_phone': '+39 0577 152 2339',
#    'distance': 26.67038363079442},
#   {'id': 'xc34kHdST6Y_mxYUhdXiQg',
#    'alias': 'il-bargello-siena',
#    'name': 'Il Bargello',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/wVkGwIWIFuyKmYPWO7y7dA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/il-bargello-siena?adjust_creative=0k5_VJSyIM2A1YDO2o8Iyw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=0k5_VJSyIM2A1YDO2o8Iyw',
#    'review_count': 20,
#    'categories': [{'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'trattorie', 'title': 'Trattorie'},
#     {'alias': 'tuscan', 'title': 'Tuscan'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 43.31796, 'longitude': 11.33072},
#    'transactions': [],
#    'price': '€€',
#    'location': {'address1': "Via di Citta' 53",
#     'address2': None,
#     'address3': None,
#     'city': 'Siena',
#     'zip_code': '53100',
#     'country': 'IT',
#     'state': 'SI',
#     'display_address': ["Via di Citta' 53", '53100 Siena', 'Italy']},
#    'phone': '+390577045649',
#    'display_phone': '+39 0577 045649',
#    'distance': 465.0703473576824},
#   {'id': 'adYNbvvBlwmsIQG8mBPESA',
#    'alias': 'antica-osteria-da-divo-siena',
#    'name': 'Antica Osteria da Divo',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/4ghKoT3MpzGpRQhLvfOkJg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/antica-osteria-da-divo-siena?adjust_creative=0k5_VJSyIM2A1YDO2o8Iyw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=0k5_VJSyIM2A1YDO2o8Iyw',
#    'review_count': 62,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 43.3178905, 'longitude': 11.3279767},
#    'transactions': [],
#    'price': '€€€',
#    'location': {'address1': 'Via Franciosa 25',
#     'address2': '',
#     'address3': '',
#     'city': 'Siena',
#     'zip_code': '53100',
#     'country': 'IT',
#     'state': 'SI',
#     'display_address': ['Via Franciosa 25', '53100 Siena', 'Italy']},
#    'phone': '+390577284381',
#    'display_phone': '+39 0577 284381',
#    'distance': 412.4836573565211},
#   {'id': 'vtlYiBJVRD5-kf9H9xL-rg',
#    'alias': 'duomo-di-siena-siena',
#    'name': 'Duomo di Siena',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/W7iyvFHk4eVtYOC8yI2vuQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/duomo-di-siena-siena?adjust_creative=0k5_VJSyIM2A1YDO2o8Iyw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=0k5_VJSyIM2A1YDO2o8Iyw',
#    'review_count': 39,
#    'categories': [{'alias': 'landmarks',
#      'title': 'Landmarks & Historical Buildings'},
#     {'alias': 'churches', 'title': 'Churches'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 43.3176574707031,
#     'longitude': 11.3284664154053},
#    'transactions': [],
#    'location': {'address1': 'Piazza del Duomo 8',
#     'address2': '',
#     'address3': '',
#     'city': 'Siena',
#     'zip_code': '53100',
#     'country': 'IT',
#     'state': 'SI',
#     'display_address': ['Piazza del Duomo 8', '53100 Siena', 'Italy']},
#    'phone': '+390577286300',
#    'display_phone': '+39 0577 286300',
#    'distance': 440.2582714565261},
#   {'id': 'Qp81ff_G-hgk4GOp7XbZdg',
#    'alias': 'nannini-siena-2',
#    'name': 'Nannini',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/5LiCHIJ9p9OIn05Jy-idSQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/nannini-siena-2?adjust_creative=0k5_VJSyIM2A1YDO2o8Iyw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=0k5_VJSyIM2A1YDO2o8Iyw',
#    'review_count': 20,
#    'categories': [{'alias': 'desserts', 'title': 'Desserts'},
#     {'alias': 'cakeshop', 'title': 'Patisserie/Cake Shop'},
#     {'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 43.319562, 'longitude': 11.331666},
#    'transactions': [],
#    'price': '€€',
#    'location': {'address1': 'Via Banchi di Sopra 24',
#     'address2': None,
#     'address3': None,
#     'city': 'Siena',
#     'zip_code': '53100',
#     'country': 'IT',
#     'state': 'SI',
#     'display_address': ['Via Banchi di Sopra 24', '53100 Siena', 'Italy']},
#    'phone': '+390577236009',
#    'display_phone': '+39 0577 236009',
#    'distance': 376.59039734346146},
#   {'id': 'pcTsjukTtxzc5TLjOFpVMw',
#    'alias': 'ristorante-san-domenico-siena',
#    'name': 'Ristorante San Domenico',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/YZrGqIfe0mSbC2RRGqK5VA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ristorante-san-domenico-siena?adjust_creative=0k5_VJSyIM2A1YDO2o8Iyw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=0k5_VJSyIM2A1YDO2o8Iyw',
#    'review_count': 7,
#    'categories': [{'alias': 'tuscan', 'title': 'Tuscan'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 43.3201345, 'longitude': 11.3280716},
#    'transactions': [],
#    'price': '€€',
#    'location': {'address1': 'Via di camporegio 15',
#     'address2': '',
#     'address3': '',
#     'city': 'Siena',
#     'zip_code': '53100',
#     'country': 'IT',
#     'state': 'SI',
#     'display_address': ['Via di camporegio 15', '53100 Siena', 'Italy']},
#    'phone': '+3905771881662',
#    'display_phone': '+39 0577 188 1662',
#    'distance': 163.26245625500457},
#   {'id': '-eEnvNTEf2gsw0gk-EdXZQ',
#    'alias': 'fonte-giusta-siena',
#    'name': 'Fonte Giusta',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/P-0NGGd1xJiMi_5z5eshpg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/fonte-giusta-siena?adjust_creative=0k5_VJSyIM2A1YDO2o8Iyw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=0k5_VJSyIM2A1YDO2o8Iyw',
#    'review_count': 18,
#    'categories': [{'alias': 'tuscan', 'title': 'Tuscan'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 43.32567, 'longitude': 11.3271599},
#    'transactions': [],
#    'price': '€€',
#    'location': {'address1': 'Via Camollia 102',
#     'address2': None,
#     'address3': None,
#     'city': 'Siena',
#     'zip_code': '53100',
#     'country': 'IT',
#     'state': 'SI',
#     'display_address': ['Via Camollia 102', '53100 Siena', 'Italy']},
#    'phone': '+39057740506',
#    'display_phone': '+39 0577 40506',
#    'distance': 454.8748511370559},
#   {'id': 'AhrYz7DIpvsLmglNb8SpTA',
#    'alias': 'taverna-di-cecco-siena',
#    'name': 'Taverna di Cecco',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/lAO1UAvmJlVqLqQctKkKlA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/taverna-di-cecco-siena?adjust_creative=0k5_VJSyIM2A1YDO2o8Iyw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=0k5_VJSyIM2A1YDO2o8Iyw',
#    'review_count': 50,
#    'categories': [{'alias': 'tuscan', 'title': 'Tuscan'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 43.31999, 'longitude': 11.33196},
#    'transactions': [],
#    'price': '€€',
#    'location': {'address1': 'Via Cecco Angliolieri 19',
#     'address2': None,
#     'address3': None,
#     'city': 'Siena',
#     'zip_code': '53100',
#     'country': 'IT',
#     'state': 'SI',
#     'display_address': ['Via Cecco Angliolieri 19', '53100 Siena', 'Italy']},
#    'phone': '+390577288518',
#    'display_phone': '+39 0577 288518',
#    'distance': 369.28804702622904},
#   {'id': '3kdP2RtsSWIjCUKS3nT_Qg',
#    'alias': 'prètto-siena',
#    'name': 'Prètto',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/NNuO9XvkzqD6KnJ7G9DM9w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/pr%C3%A8tto-siena?adjust_creative=0k5_VJSyIM2A1YDO2o8Iyw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=0k5_VJSyIM2A1YDO2o8Iyw',
#    'review_count': 12,
#    'categories': [{'alias': 'salumerie', 'title': 'Salumerie'},
#     {'alias': 'cheese', 'title': 'Cheese Shops'},
#     {'alias': 'tuscan', 'title': 'Tuscan'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 43.3193310254123,
#     'longitude': 11.3308340683579},
#    'transactions': [],
#    'price': '€',
#    'location': {'address1': 'Via dei Termini 4',
#     'address2': '',
#     'address3': '',
#     'city': 'Siena',
#     'zip_code': '53100',
#     'country': 'IT',
#     'state': 'SI',
#     'display_address': ['Via dei Termini 4', '53100 Siena', 'Italy']},
#    'phone': '+390577289089',
#    'display_phone': '+39 0577 289089',
#    'distance': 343.75139114954806},
#   {'id': 'CFeFDS7oGCaELqcTpIMvWA',
#    'alias': 'la-prosciutteria-siena',
#    'name': 'La Prosciutteria',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/VuIXq7wXe19rly_Lj103Aw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/la-prosciutteria-siena?adjust_creative=0k5_VJSyIM2A1YDO2o8Iyw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=0k5_VJSyIM2A1YDO2o8Iyw',
#    'review_count': 34,
#    'categories': [{'alias': 'wine_bars', 'title': 'Wine Bars'},
#     {'alias': 'tuscan', 'title': 'Tuscan'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 43.318021, 'longitude': 11.335231},
#    'transactions': [],
#    'price': '€€',
#    'location': {'address1': 'Via di Pantaneto',
#     'address2': '',
#     'address3': '',
#     'city': 'Siena',
#     'zip_code': '53100',
#     'country': 'IT',
#     'state': 'SI',
#     'display_address': ['Via di Pantaneto', '53100 Siena', 'Italy']},
#    'phone': '+39057742026',
#    'display_phone': '+39 0577 42026',
#    'distance': 718.1260379947934},
#   {'id': 'SKykLSSbrICvEyQhCOrrIA',
#    'alias': 'il-masgalano-siena',
#    'name': 'Il Masgalano',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/7j-21g2ZfGcjF0Z4FD3RxA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/il-masgalano-siena?adjust_creative=0k5_VJSyIM2A1YDO2o8Iyw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=0k5_VJSyIM2A1YDO2o8Iyw',
#    'review_count': 4,
#    'categories': [{'alias': 'tuscan', 'title': 'Tuscan'},
#     {'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 43.32034, 'longitude': 11.32722},
#    'transactions': [],
#    'price': '€€',
#    'location': {'address1': 'Via Camporegio 1',
#     'address2': None,
#     'address3': None,
#     'city': 'Siena',
#     'zip_code': '53100',
#     'country': 'IT',
#     'state': 'SI',
#     'display_address': ['Via Camporegio 1', '53100 Siena', 'Italy']},
#    'phone': '+39057744349',
#    'display_phone': '+39 0577 44349',
#    'distance': 152.85688893521254},
#   {'id': 'kklzoCN71e-RymlI-0tuDw',
#    'alias': 'antica-trattoria-papei-siena',
#    'name': 'Antica Trattoria Papei',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/JpzMoRdkfv2dygBy-usX-Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/antica-trattoria-papei-siena?adjust_creative=0k5_VJSyIM2A1YDO2o8Iyw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=0k5_VJSyIM2A1YDO2o8Iyw',
#    'review_count': 34,
#    'categories': [{'alias': 'tuscan', 'title': 'Tuscan'},
#     {'alias': 'trattorie', 'title': 'Trattorie'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 43.31764, 'longitude': 11.33207},
#    'transactions': [],
#    'price': '€€€',
#    'location': {'address1': 'Via del Mercato 6',
#     'address2': None,
#     'address3': None,
#     'city': 'Siena',
#     'zip_code': '53100',
#     'country': 'IT',
#     'state': 'SI',
#     'display_address': ['Via del Mercato 6', '53100 Siena', 'Italy']},
#    'phone': '+390577280894',
#    'display_phone': '+39 0577 280894',
#    'distance': 554.2309210813031},
#   {'id': 'sadSlmzqtd339Mzra0JRzg',
#    'alias': 'pizzeria-di-nonno-mede-siena',
#    'name': 'Pizzeria di Nonno Mede',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/TP2IegtAlj-COF-cDT7gTg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/pizzeria-di-nonno-mede-siena?adjust_creative=0k5_VJSyIM2A1YDO2o8Iyw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=0k5_VJSyIM2A1YDO2o8Iyw',
#    'review_count': 16,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'tuscan', 'title': 'Tuscan'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 43.32018, 'longitude': 11.32839},
#    'transactions': [],
#    'price': '€€',
#    'location': {'address1': 'Via Camporegio 21',
#     'address2': None,
#     'address3': None,
#     'city': 'Siena',
#     'zip_code': '53100',
#     'country': 'IT',
#     'state': 'SI',
#     'display_address': ['Via Camporegio 21', '53100 Siena', 'Italy']},
#    'phone': '+390577247966',
#    'display_phone': '+39 0577 247966',
#    'distance': 151.9259338486539},
#   {'id': 'KuGyofyUHYhTShJsk36iYQ',
#    'alias': 'mugolone-siena',
#    'name': 'Mugolone',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/ykBCR3mv5JOUnwVKlBm1aQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/mugolone-siena?adjust_creative=0k5_VJSyIM2A1YDO2o8Iyw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=0k5_VJSyIM2A1YDO2o8Iyw',
#    'review_count': 7,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'gluten_free', 'title': 'Gluten-Free'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 43.318409, 'longitude': 11.3302298},
#    'transactions': [],
#    'location': {'address1': 'Via dei Pellegrini 8',
#     'address2': '',
#     'address3': '',
#     'city': 'Siena',
#     'zip_code': '53100',
#     'country': 'IT',
#     'state': 'SI',
#     'display_address': ['Via dei Pellegrini 8', '53100 Siena', 'Italy']},
#    'phone': '+390577283235',
#    'display_phone': '+39 0577 283235',
#    'distance': 400.02181789119714}],
#  'total': 202,
#  'region': {'center': {'longitude': 11.327948, 'latitude': 43.3216}}}

# %% [markdown]
# Parse through the response to get the POI (such as restaurants, bars, etc) details you want (ratings, name, location, etc)

# %%
yelp_res_lst = []
for yelp_res_json in yelp_res_json_lst:
    yelp_result = yelp_res_json['businesses']
    for i in range(len(yelp_result)):
        dict = {}
        dict['name'] = yelp_result[i]['name']
        dict['address'] = yelp_result[i]['location']['address1']
        dict['rating'] = yelp_result[i]['rating']
        if yelp_result[i]['categories']:
            dict['category'] = yelp_result[i]['categories'][0]['title']
        yelp_res_lst.append(dict)

yelp_res_lst
# Out:
# [{'name': 'La Taverna di San Giuseppe',
#   'address': 'Via Giovanni Dupre 132',
#   'rating': 5.0,
#   'category': 'Tuscan'},
#  {'name': 'Zest',
#   'address': "Costa di Sant'antonio 13",
#   'rating': 4.5,
#   'category': 'Italian'},
#  {'name': 'La Chiacchiera',
#   'address': 'Via Costa di San Antonio 4',
#   'rating': 4.0,
#   'category': 'Italian'},
#  {'name': 'Café Nannini',
#   'address': 'Piazza Matteotti 32',
#   'rating': 4.5,
#   'category': 'Cafes'},
#  {'name': 'Compagnia dei Vinattieri',
#   'address': 'Via delle Terme, 79',
#   'rating': 4.0,
#   'category': 'Tuscan'},
#  {'name': 'Salefino Vino e Cucina',
#   'address': 'Via degli Umiliati 1',
#   'rating': 4.5,
#   'category': 'Tuscan'},
#  {'name': 'Pizzeria alle Scalette',
#   'address': 'Viale Curtatone 18',
#   'rating': 4.5,
#   'category': 'Pizza'},
#  {'name': 'Il Bargello',
#   'address': "Via di Citta' 53",
#   'rating': 4.5,
#   'category': 'Bars'},
#  {'name': 'Antica Osteria da Divo',
#   'address': 'Via Franciosa 25',
#   'rating': 4.0,
#   'category': 'Italian'},
#  {'name': 'Duomo di Siena',
#   'address': 'Piazza del Duomo 8',
#   'rating': 5.0,
#   'category': 'Landmarks & Historical Buildings'},
#  {'name': 'Nannini',
#   'address': 'Via Banchi di Sopra 24',
#   'rating': 4.0,
#   'category': 'Desserts'},
#  {'name': 'Ristorante San Domenico',
#   'address': 'Via di camporegio 15',
#   'rating': 4.5,
#   'category': 'Tuscan'},
#  {'name': 'Fonte Giusta',
#   'address': 'Via Camollia 102',
#   'rating': 4.5,
#   'category': 'Tuscan'},
#  {'name': 'Taverna di Cecco',
#   'address': 'Via Cecco Angliolieri 19',
#   'rating': 4.5,
#   'category': 'Tuscan'},
#  {'name': 'Prètto',
#   'address': 'Via dei Termini 4',
#   'rating': 4.0,
#   'category': 'Salumerie'},
#  {'name': 'La Prosciutteria',
#   'address': 'Via di Pantaneto',
#   'rating': 4.5,
#   'category': 'Wine Bars'},
#  {'name': 'Il Masgalano',
#   'address': 'Via Camporegio 1',
#   'rating': 5.0,
#   'category': 'Tuscan'},
#  {'name': 'Antica Trattoria Papei',
#   'address': 'Via del Mercato 6',
#   'rating': 4.0,
#   'category': 'Tuscan'},
#  {'name': 'Pizzeria di Nonno Mede',
#   'address': 'Via Camporegio 21',
#   'rating': 4.0,
#   'category': 'Pizza'},
#  {'name': 'Mugolone',
#   'address': 'Via dei Pellegrini 8',
#   'rating': 5.0,
#   'category': 'Italian'},
#  {'name': 'La Taverna di San Giuseppe',
#   'address': 'Via Giovanni Dupre 132',
#   'rating': 5.0,
#   'category': 'Tuscan'},
#  {'name': 'Vi Vace',
#   'address': 'Via Stalloreggi 64',
#   'rating': 4.5,
#   'category': 'Pizza'},
#  {'name': 'Il Bargello',
#   'address': "Via di Citta' 53",
#   'rating': 4.5,
#   'category': 'Bars'},
#  {'name': 'Numero Unico',
#   'address': 'Via di Citta 125',
#   'rating': 4.5,
#   'category': 'Italian'},
#  {'name': 'Ri.Me.',
#   'address': 'Via Giovanni Duprè 90',
#   'rating': 4.5,
#   'category': 'Tuscan'},
#  {'name': 'Antica Trattoria Papei',
#   'address': 'Via del Mercato 6',
#   'rating': 4.0,
#   'category': 'Tuscan'},
#  {'name': 'Ostaria dá Cice',
#   'address': 'Via San Pietro 32',
#   'rating': 4.0,
#   'category': 'Italian'},
#  {'name': 'Duomo di Siena',
#   'address': 'Piazza del Duomo 8',
#   'rating': 5.0,
#   'category': 'Landmarks & Historical Buildings'},
#  {'name': 'Antica Osteria da Divo',
#   'address': 'Via Franciosa 25',
#   'rating': 4.0,
#   'category': 'Italian'},
#  {'name': 'Pizzicheria de Miccoli',
#   'address': 'Via di Città 95',
#   'rating': 4.5,
#   'category': 'Pizza'},
#  {'name': 'La Prosciutteria',
#   'address': 'Via di Pantaneto',
#   'rating': 4.5,
#   'category': 'Wine Bars'},
#  {'name': 'Zest',
#   'address': "Costa di Sant'antonio 13",
#   'rating': 4.5,
#   'category': 'Italian'},
#  {'name': 'Gallo Nero',
#   'address': 'Via del Porrione 65',
#   'rating': 4.5,
#   'category': 'Tuscan'},
#  {'name': 'Osteria Nonna Gina',
#   'address': 'Via Piano dei Mantellini, 2',
#   'rating': 4.0,
#   'category': 'Tuscan'},
#  {'name': 'Ristorante San Desiderio',
#   'address': 'Piazza L. Bonelli 2',
#   'rating': 4.0,
#   'category': 'Italian'},
#  {'name': 'Osteria Castelvecchio',
#   'address': 'Via Castelvecchio 65',
#   'rating': 4.5,
#   'category': 'Tuscan'},
#  {'name': 'Antica Trattoria Stalloreggi',
#   'address': 'Via Stalloreggi 37',
#   'rating': 4.0,
#   'category': 'Tuscan'},
#  {'name': 'Mugolone',
#   'address': 'Via dei Pellegrini 8',
#   'rating': 5.0,
#   'category': 'Italian'},
#  {'name': 'Osteria Permalico',
#   'address': 'Via Costa Larga 4',
#   'rating': 4.5,
#   'category': 'Desserts'},
#  {'name': 'Osteria Il Carroccio',
#   'address': 'Via Casato di Sotto 32',
#   'rating': 4.5,
#   'category': 'Italian'},
#  {'name': 'La Taverna di San Giuseppe',
#   'address': 'Via Giovanni Dupre 132',
#   'rating': 5.0,
#   'category': 'Tuscan'},
#  {'name': 'La Prosciutteria',
#   'address': 'Via di Pantaneto',
#   'rating': 4.5,
#   'category': 'Wine Bars'},
#  {'name': 'Antica Trattoria Papei',
#   'address': 'Via del Mercato 6',
#   'rating': 4.0,
#   'category': 'Tuscan'},
#  {'name': 'Gallo Nero',
#   'address': 'Via del Porrione 65',
#   'rating': 4.5,
#   'category': 'Tuscan'},
#  {'name': 'Il Bargello',
#   'address': "Via di Citta' 53",
#   'rating': 4.5,
#   'category': 'Bars'},
#  {'name': 'Bio & Chocolate',
#   'address': 'Via Pantaneto 75',
#   'rating': 5.0,
#   'category': 'Cafes'},
#  {'name': 'Osteria La Sosta di Violante',
#   'address': 'Via di Pantaneto 115',
#   'rating': 4.5,
#   'category': 'Tuscan'},
#  {'name': 'Duomo di Siena',
#   'address': 'Piazza del Duomo 8',
#   'rating': 5.0,
#   'category': 'Landmarks & Historical Buildings'},
#  {'name': 'Zest',
#   'address': "Costa di Sant'antonio 13",
#   'rating': 4.5,
#   'category': 'Italian'},
#  {'name': 'Antica Osteria da Divo',
#   'address': 'Via Franciosa 25',
#   'rating': 4.0,
#   'category': 'Italian'},
#  {'name': 'Ri.Me.',
#   'address': 'Via Giovanni Duprè 90',
#   'rating': 4.5,
#   'category': 'Tuscan'},
#  {'name': 'Vi Vace',
#   'address': 'Via Stalloreggi 64',
#   'rating': 4.5,
#   'category': 'Pizza'},
#  {'name': 'Numero Unico',
#   'address': 'Via di Citta 125',
#   'rating': 4.5,
#   'category': 'Italian'},
#  {'name': 'Taverna di Cecco',
#   'address': 'Via Cecco Angliolieri 19',
#   'rating': 4.5,
#   'category': 'Tuscan'},
#  {'name': 'Osteria Babazuf',
#   'address': 'Via di Pantaneto, 85',
#   'rating': 4.5,
#   'category': 'Pizza'},
#  {'name': 'Pizzicheria de Miccoli',
#   'address': 'Via di Città 95',
#   'rating': 4.5,
#   'category': 'Pizza'},
#  {'name': 'Osteria Le Logge',
#   'address': 'Via del Porrione 33',
#   'rating': 4.0,
#   'category': 'Italian'},
#  {'name': "L'orto de' pecci",
#   'address': 'Via di Porta Giustizia 39',
#   'rating': 5.0,
#   'category': 'Italian'},
#  {'name': 'Nannini',
#   'address': 'Via Banchi di Sopra 24',
#   'rating': 4.0,
#   'category': 'Desserts'},
#  {'name': 'Salefino Vino e Cucina',
#   'address': 'Via degli Umiliati 1',
#   'rating': 4.5,
#   'category': 'Tuscan'},
#  {'name': 'La Taverna di San Giuseppe',
#   'address': 'Via Giovanni Dupre 132',
#   'rating': 5.0,
#   'category': 'Tuscan'},
#  {'name': 'Zest',
#   'address': "Costa di Sant'antonio 13",
#   'rating': 4.5,
#   'category': 'Italian'},
#  {'name': 'Antica Osteria da Divo',
#   'address': 'Via Franciosa 25',
#   'rating': 4.0,
#   'category': 'Italian'},
#  {'name': 'Duomo di Siena',
#   'address': 'Piazza del Duomo 8',
#   'rating': 5.0,
#   'category': 'Landmarks & Historical Buildings'},
#  {'name': 'Il Bargello',
#   'address': "Via di Citta' 53",
#   'rating': 4.5,
#   'category': 'Bars'},
#  {'name': 'Café Nannini',
#   'address': 'Piazza Matteotti 32',
#   'rating': 4.5,
#   'category': 'Cafes'},
#  {'name': 'La Prosciutteria',
#   'address': 'Via di Pantaneto',
#   'rating': 4.5,
#   'category': 'Wine Bars'},
#  {'name': 'La Chiacchiera',
#   'address': 'Via Costa di San Antonio 4',
#   'rating': 4.0,
#   'category': 'Italian'},
#  {'name': 'Vi Vace',
#   'address': 'Via Stalloreggi 64',
#   'rating': 4.5,
#   'category': 'Pizza'},
#  {'name': 'Fonte Giusta',
#   'address': 'Via Camollia 102',
#   'rating': 4.5,
#   'category': 'Tuscan'},
#  {'name': 'Antica Trattoria Papei',
#   'address': 'Via del Mercato 6',
#   'rating': 4.0,
#   'category': 'Tuscan'},
#  {'name': 'Numero Unico',
#   'address': 'Via di Citta 125',
#   'rating': 4.5,
#   'category': 'Italian'},
#  {'name': 'Salefino Vino e Cucina',
#   'address': 'Via degli Umiliati 1',
#   'rating': 4.5,
#   'category': 'Tuscan'},
#  {'name': 'Taverna di Cecco',
#   'address': 'Via Cecco Angliolieri 19',
#   'rating': 4.5,
#   'category': 'Tuscan'},
#  {'name': 'Il Masgalano',
#   'address': 'Via Camporegio 1',
#   'rating': 5.0,
#   'category': 'Tuscan'},
#  {'name': 'Ristorante San Domenico',
#   'address': 'Via di camporegio 15',
#   'rating': 4.5,
#   'category': 'Tuscan'},
#  {'name': 'Compagnia dei Vinattieri',
#   'address': 'Via delle Terme, 79',
#   'rating': 4.0,
#   'category': 'Tuscan'},
#  {'name': 'Pizzicheria de Miccoli',
#   'address': 'Via di Città 95',
#   'rating': 4.5,
#   'category': 'Pizza'},
#  {'name': 'Gallo Nero',
#   'address': 'Via del Porrione 65',
#   'rating': 4.5,
#   'category': 'Tuscan'},
#  {'name': 'Nannini',
#   'address': 'Via Banchi di Sopra 24',
#   'rating': 4.0,
#   'category': 'Desserts'},
#  {'name': 'Ravioli Wang',
#   'address': 'Viale Vittorio Emanuele II 38',
#   'rating': 5.0,
#   'category': 'Chinese'},
#  {'name': 'Zest',
#   'address': "Costa di Sant'antonio 13",
#   'rating': 4.5,
#   'category': 'Italian'},
#  {'name': 'Fonte Giusta',
#   'address': 'Via Camollia 102',
#   'rating': 4.5,
#   'category': 'Tuscan'},
#  {'name': 'Il Vinaio',
#   'address': 'Via Camollia 167',
#   'rating': 4.5,
#   'category': 'Sandwiches'},
#  {'name': 'Taverna di Cecco',
#   'address': 'Via Cecco Angliolieri 19',
#   'rating': 4.5,
#   'category': 'Tuscan'},
#  {'name': 'Salefino Vino e Cucina',
#   'address': 'Via degli Umiliati 1',
#   'rating': 4.5,
#   'category': 'Tuscan'},
#  {'name': 'Café Nannini',
#   'address': 'Piazza Matteotti 32',
#   'rating': 4.5,
#   'category': 'Cafes'},
#  {'name': 'La Chiacchiera',
#   'address': 'Via Costa di San Antonio 4',
#   'rating': 4.0,
#   'category': 'Italian'},
#  {'name': 'Compagnia dei Vinattieri',
#   'address': 'Via delle Terme, 79',
#   'rating': 4.0,
#   'category': 'Tuscan'},
#  {'name': 'Ristorante Pizzeria I Gabellieri',
#   'address': 'Via V. Emanuele 75',
#   'rating': 4.0,
#   'category': 'Pizza'},
#  {'name': 'Osteria di Kamollia',
#   'address': 'Via di Camollia 114',
#   'rating': 4.0,
#   'category': 'Tuscan'},
#  {'name': 'Ristorante San Domenico',
#   'address': 'Via di camporegio 15',
#   'rating': 4.5,
#   'category': 'Tuscan'},
#  {'name': "L'oro di Siena",
#   'address': 'Via Garibaldi 61',
#   'rating': 5.0,
#   'category': 'Pizza'},
#  {'name': 'Osteria Il Grattacielo',
#   'address': 'Via Pontani 8',
#   'rating': 4.0,
#   'category': 'Italian'},
#  {'name': 'Ristorante Da Enzo',
#   'address': 'Via Camollia 49',
#   'rating': 4.5,
#   'category': 'Italian'},
#  {'name': 'Pizzeria alle Scalette',
#   'address': 'Viale Curtatone 18',
#   'rating': 4.5,
#   'category': 'Pizza'},
#  {'name': 'Buti pasticceria',
#   'address': 'Viale Vittorio Emanuele II, 53',
#   'rating': 5.0,
#   'category': 'Chocolatiers & Shops'},
#  {'name': 'Il Masgalano',
#   'address': 'Via Camporegio 1',
#   'rating': 5.0,
#   'category': 'Tuscan'},
#  {'name': 'Cafe Berta',
#   'address': 'Piazza Guido Chigi Saracini',
#   'rating': 4.5,
#   'category': 'Cafes'},
#  {'name': 'Sushiko',
#   'address': 'Piazzale Carlo Rosselli 25',
#   'rating': 4.0,
#   'category': 'Sushi Bars'},
#  {'name': 'Donna Ripalta',
#   'address': 'Viale Pietro Toselli 41',
#   'rating': 4.0,
#   'category': 'Tuscan'},
#  {'name': 'Havana Club',
#   'address': 'Piazza Maestri del Lavoro 27',
#   'rating': 5.0,
#   'category': 'Cuban'},
#  {'name': 'Albergo Certosa di Maggiano',
#   'address': 'Str. di Certosa, 82',
#   'rating': 5.0,
#   'category': 'Hotels & Travel'},
#  {'name': 'Fontebecci',
#   'address': 'Via Fiorentina 133',
#   'rating': 2.0,
#   'category': 'Pizza'},
#  {'name': "Mc Donald's",
#   'address': 'Via Fiorentina 124',
#   'rating': 2.0,
#   'category': 'Fast Food'},
#  {'name': 'la veranda',
#   'address': 'Piazza Calabria',
#   'rating': 4.5,
#   'category': 'Italian'},
#  {'name': 'Antica Trattoria Botteganova',
#   'address': 'Strada Chiantigiana 29',
#   'rating': 5.0,
#   'category': 'Italian'},
#  {'name': "Dream Cafe'",
#   'address': 'Str. Statale 222 Chiantigiana, 13',
#   'rating': 4.0,
#   'category': 'Bars'},
#  {'name': "Skile' Music Bar",
#   'address': 'Piazza Calabria 18',
#   'rating': 3.0,
#   'category': 'Cafes'},
#  {'name': 'Dopolavoro La Foce',
#   'address': 'Strada della Vittorio 90',
#   'rating': 5.0,
#   'category': 'Italian'},
#  {'name': 'Hotel Garden',
#   'address': 'Via Custoza 2',
#   'rating': 3.0,
#   'category': 'Venues & Event Spaces'},
#  {'name': 'la veranda',
#   'address': 'Piazza Calabria',
#   'rating': 4.5,
#   'category': 'Italian'},
#  {'name': "Mc Donald's",
#   'address': 'Via Fiorentina 124',
#   'rating': 2.0,
#   'category': 'Fast Food'},
#  {'name': "Dream Cafe'",
#   'address': 'Str. Statale 222 Chiantigiana, 13',
#   'rating': 4.0,
#   'category': 'Bars'},
#  {'name': 'Fontebecci',
#   'address': 'Via Fiorentina 133',
#   'rating': 2.0,
#   'category': 'Pizza'},
#  {'name': "Skile' Music Bar",
#   'address': 'Piazza Calabria 18',
#   'rating': 3.0,
#   'category': 'Cafes'},
#  {'name': 'La Taverna di San Giuseppe',
#   'address': 'Via Giovanni Dupre 132',
#   'rating': 5.0,
#   'category': 'Tuscan'},
#  {'name': 'Duomo di Siena',
#   'address': 'Piazza del Duomo 8',
#   'rating': 5.0,
#   'category': 'Landmarks & Historical Buildings'},
#  {'name': 'La Prosciutteria',
#   'address': 'Via di Pantaneto',
#   'rating': 4.5,
#   'category': 'Wine Bars'},
#  {'name': 'Il Bargello',
#   'address': "Via di Citta' 53",
#   'rating': 4.5,
#   'category': 'Bars'},
#  {'name': 'Zest',
#   'address': "Costa di Sant'antonio 13",
#   'rating': 4.5,
#   'category': 'Italian'},
#  {'name': 'Antica Osteria da Divo',
#   'address': 'Via Franciosa 25',
#   'rating': 4.0,
#   'category': 'Italian'},
#  {'name': 'Vi Vace',
#   'address': 'Via Stalloreggi 64',
#   'rating': 4.5,
#   'category': 'Pizza'},
#  {'name': 'Fonte Giusta',
#   'address': 'Via Camollia 102',
#   'rating': 4.5,
#   'category': 'Tuscan'},
#  {'name': 'Antica Trattoria Papei',
#   'address': 'Via del Mercato 6',
#   'rating': 4.0,
#   'category': 'Tuscan'},
#  {'name': 'Numero Unico',
#   'address': 'Via di Citta 125',
#   'rating': 4.5,
#   'category': 'Italian'},
#  {'name': 'Taverna di Cecco',
#   'address': 'Via Cecco Angliolieri 19',
#   'rating': 4.5,
#   'category': 'Tuscan'},
#  {'name': 'Gallo Nero',
#   'address': 'Via del Porrione 65',
#   'rating': 4.5,
#   'category': 'Tuscan'},
#  {'name': 'Salefino Vino e Cucina',
#   'address': 'Via degli Umiliati 1',
#   'rating': 4.5,
#   'category': 'Tuscan'},
#  {'name': 'Pizzicheria de Miccoli',
#   'address': 'Via di Città 95',
#   'rating': 4.5,
#   'category': 'Pizza'},
#  {'name': 'Café Nannini',
#   'address': 'Piazza Matteotti 32',
#   'rating': 4.5,
#   'category': 'Cafes'},
#  {'name': 'La Chiacchiera',
#   'address': 'Via Costa di San Antonio 4',
#   'rating': 4.0,
#   'category': 'Italian'},
#  {'name': 'Compagnia dei Vinattieri',
#   'address': 'Via delle Terme, 79',
#   'rating': 4.0,
#   'category': 'Tuscan'},
#  {'name': 'Nannini',
#   'address': 'Via Banchi di Sopra 24',
#   'rating': 4.0,
#   'category': 'Desserts'},
#  {'name': 'Ri.Me.',
#   'address': 'Via Giovanni Duprè 90',
#   'rating': 4.5,
#   'category': 'Tuscan'},
#  {'name': 'Ostaria dá Cice',
#   'address': 'Via San Pietro 32',
#   'rating': 4.0,
#   'category': 'Italian'},
#  {'name': 'Dopolavoro La Foce',
#   'address': 'Strada della Vittorio 90',
#   'rating': 5.0,
#   'category': 'Italian'},
#  {'name': 'Fonte Giusta',
#   'address': 'Via Camollia 102',
#   'rating': 4.5,
#   'category': 'Tuscan'},
#  {'name': 'Ravioli Wang',
#   'address': 'Viale Vittorio Emanuele II 38',
#   'rating': 5.0,
#   'category': 'Chinese'},
#  {'name': 'Salefino Vino e Cucina',
#   'address': 'Via degli Umiliati 1',
#   'rating': 4.5,
#   'category': 'Tuscan'},
#  {'name': 'Il Vinaio',
#   'address': 'Via Camollia 167',
#   'rating': 4.5,
#   'category': 'Sandwiches'},
#  {'name': 'Osteria di Kamollia',
#   'address': 'Via di Camollia 114',
#   'rating': 4.0,
#   'category': 'Tuscan'},
#  {'name': 'Sushiko',
#   'address': 'Piazzale Carlo Rosselli 25',
#   'rating': 4.0,
#   'category': 'Sushi Bars'},
#  {'name': "L'oro di Siena",
#   'address': 'Via Garibaldi 61',
#   'rating': 5.0,
#   'category': 'Pizza'},
#  {'name': 'Ristorante Da Enzo',
#   'address': 'Via Camollia 49',
#   'rating': 4.5,
#   'category': 'Italian'},
#  {'name': 'Susy Sushi',
#   'address': 'Piazza Rosselli',
#   'rating': 4.0,
#   'category': 'Japanese'},
#  {'name': 'Mozzarella e Basilico',
#   'address': 'Piazzale Rosselli 25',
#   'rating': 1.0,
#   'category': 'Trattorie'},
#  {'name': 'La Grotta di San Francesco',
#   'address': 'Via Camollia 25',
#   'rating': 5.0,
#   'category': 'Seafood'},
#  {'name': 'Cafe Berta',
#   'address': 'Piazza Guido Chigi Saracini',
#   'rating': 4.5,
#   'category': 'Cafes'},
#  {'name': 'Tia Loca',
#   'address': 'Via Bettino Ricasoli 55',
#   'rating': 2.5,
#   'category': 'Pizza'},
#  {'name': 'Buti pasticceria',
#   'address': 'Viale Vittorio Emanuele II, 53',
#   'rating': 5.0,
#   'category': 'Chocolatiers & Shops'},
#  {'name': 'Pasta Mondo',
#   'address': 'Via Camollia 173',
#   'rating': 5.0,
#   'category': 'Pizza'},
#  {'name': 'Corsini',
#   'address': 'Via Armando Diaz 4',
#   'rating': 3.5,
#   'category': 'Desserts'},
#  {'name': 'La Mandorla',
#   'address': 'Via Camollia 36',
#   'rating': 5.0,
#   'category': 'Desserts'},
#  {'name': 'Cartazucchero',
#   'address': 'Via Camollia 92',
#   'rating': 5.0,
#   'category': 'Used Bookstore'},
#  {'name': 'Ristorante Minohana',
#   'address': 'Viale Vittorio Emanuele II 32',
#   'rating': 1.0,
#   'category': 'Tuscan'},
#  {'name': 'Ristorante Pizzeria I Gabellieri',
#   'address': 'Via V. Emanuele 75',
#   'rating': 4.0,
#   'category': 'Pizza'},
#  {'name': 'la veranda',
#   'address': 'Piazza Calabria',
#   'rating': 4.5,
#   'category': 'Italian'},
#  {'name': "Skile' Music Bar",
#   'address': 'Piazza Calabria 18',
#   'rating': 3.0,
#   'category': 'Cafes'},
#  {'name': 'Antica Trattoria Botteganova',
#   'address': 'Strada Chiantigiana 29',
#   'rating': 5.0,
#   'category': 'Italian'},
#  {'name': "Mc Donald's",
#   'address': 'Via Fiorentina 124',
#   'rating': 2.0,
#   'category': 'Fast Food'},
#  {'name': "Dream Cafe'",
#   'address': 'Str. Statale 222 Chiantigiana, 13',
#   'rating': 4.0,
#   'category': 'Bars'},
#  {'name': 'Fontebecci',
#   'address': 'Via Fiorentina 133',
#   'rating': 2.0,
#   'category': 'Pizza'},
#  {'name': 'Il Bargello',
#   'address': "Via di Citta' 53",
#   'rating': 4.5,
#   'category': 'Bars'},
#  {'name': 'Fonte Giusta',
#   'address': 'Via Camollia 102',
#   'rating': 4.5,
#   'category': 'Tuscan'},
#  {'name': 'Zest',
#   'address': "Costa di Sant'antonio 13",
#   'rating': 4.5,
#   'category': 'Italian'},
#  {'name': 'La Prosciutteria',
#   'address': 'Via di Pantaneto',
#   'rating': 4.5,
#   'category': 'Wine Bars'},
#  {'name': 'Antica Osteria da Divo',
#   'address': 'Via Franciosa 25',
#   'rating': 4.0,
#   'category': 'Italian'},
#  {'name': "L'oro di Siena",
#   'address': 'Via Garibaldi 61',
#   'rating': 5.0,
#   'category': 'Pizza'},
#  {'name': 'Salefino Vino e Cucina',
#   'address': 'Via degli Umiliati 1',
#   'rating': 4.5,
#   'category': 'Tuscan'},
#  {'name': 'Taverna di Cecco',
#   'address': 'Via Cecco Angliolieri 19',
#   'rating': 4.5,
#   'category': 'Tuscan'},
#  {'name': 'Café Nannini',
#   'address': 'Piazza Matteotti 32',
#   'rating': 4.5,
#   'category': 'Cafes'},
#  {'name': 'La Chiacchiera',
#   'address': 'Via Costa di San Antonio 4',
#   'rating': 4.0,
#   'category': 'Italian'},
#  {'name': 'Gallo Nero',
#   'address': 'Via del Porrione 65',
#   'rating': 4.5,
#   'category': 'Tuscan'},
#  {'name': 'Compagnia dei Vinattieri',
#   'address': 'Via delle Terme, 79',
#   'rating': 4.0,
#   'category': 'Tuscan'},
#  {'name': 'Il Vinaio',
#   'address': 'Via Camollia 167',
#   'rating': 4.5,
#   'category': 'Sandwiches'},
#  {'name': 'Nannini',
#   'address': 'Via Banchi di Sopra 24',
#   'rating': 4.0,
#   'category': 'Desserts'},
#  {'name': 'Osteria di Kamollia',
#   'address': 'Via di Camollia 114',
#   'rating': 4.0,
#   'category': 'Tuscan'},
#  {'name': 'Mugolone',
#   'address': 'Via dei Pellegrini 8',
#   'rating': 5.0,
#   'category': 'Italian'},
#  {'name': 'Ravioli Wang',
#   'address': 'Viale Vittorio Emanuele II 38',
#   'rating': 5.0,
#   'category': 'Chinese'},
#  {'name': 'Ristorante San Desiderio',
#   'address': 'Piazza L. Bonelli 2',
#   'rating': 4.0,
#   'category': 'Italian'},
#  {'name': 'Prètto',
#   'address': 'Via dei Termini 4',
#   'rating': 4.0,
#   'category': 'Salumerie'},
#  {'name': 'Te Ke Voi',
#   'address': 'Vicoli San Pietro 4',
#   'rating': 4.5,
#   'category': 'Pizza'},
#  {'name': 'Osteria Nonna Gina',
#   'address': 'Via Piano dei Mantellini, 2',
#   'rating': 4.0,
#   'category': 'Tuscan'},
#  {'name': 'Da Michele',
#   'address': 'Strada Massetana 64',
#   'rating': 5.0,
#   'category': 'Tuscan'},
#  {'name': 'Sotto le Fonti',
#   'address': 'Via Esterna di Fontebranda 114',
#   'rating': 4.5,
#   'category': 'Pizza'},
#  {'name': 'Biovita',
#   'address': 'Via Massetana Romana 54',
#   'rating': 5.0,
#   'category': 'Cafeteria'},
#  {'name': 'Da Michele',
#   'address': 'Strada Massetana 64',
#   'rating': 3.0,
#   'category': 'Tuscan'},
#  {'name': 'BAR Il Barrino',
#   'address': 'Str. Massetana Romana, 5',
#   'rating': 5.0,
#   'category': 'Bars'},
#  {'name': 'BAR dei Mantellini di Melani Fabiola',
#   'address': 'Via Piano dei Mantellini, 22',
#   'rating': 5.0,
#   'category': 'Bars'},
#  {'name': 'Nannini',
#   'address': 'Via Banchi di Sopra 24',
#   'rating': 2.0,
#   'category': 'Cafeteria'},
#  {'name': 'Fontebranda',
#   'address': 'Via di Fontebranda 73',
#   'rating': 4.0,
#   'category': 'Landmarks & Historical Buildings'},
#  {'name': 'La Taverna di San Giuseppe',
#   'address': 'Via Giovanni Dupre 132',
#   'rating': 5.0,
#   'category': 'Tuscan'},
#  {'name': 'Il Bargello',
#   'address': "Via di Citta' 53",
#   'rating': 4.5,
#   'category': 'Bars'},
#  {'name': 'La Prosciutteria',
#   'address': 'Via di Pantaneto',
#   'rating': 4.5,
#   'category': 'Wine Bars'},
#  {'name': 'Antica Trattoria Papei',
#   'address': 'Via del Mercato 6',
#   'rating': 4.0,
#   'category': 'Tuscan'},
#  {'name': 'Numero Unico',
#   'address': 'Via di Citta 125',
#   'rating': 4.5,
#   'category': 'Italian'},
#  {'name': 'Ri.Me.',
#   'address': 'Via Giovanni Duprè 90',
#   'rating': 4.5,
#   'category': 'Tuscan'},
#  {'name': 'Gallo Nero',
#   'address': 'Via del Porrione 65',
#   'rating': 4.5,
#   'category': 'Tuscan'},
#  {'name': 'Nannini',
#   'address': 'Via Banchi di Sopra 24',
#   'rating': 4.0,
#   'category': 'Desserts'},
#  {'name': 'Duomo di Siena',
#   'address': 'Piazza del Duomo 8',
#   'rating': 5.0,
#   'category': 'Landmarks & Historical Buildings'},
#  {'name': 'Pizzicheria de Miccoli',
#   'address': 'Via di Città 95',
#   'rating': 4.5,
#   'category': 'Pizza'},
#  {'name': 'Zest',
#   'address': "Costa di Sant'antonio 13",
#   'rating': 4.5,
#   'category': 'Italian'},
#  {'name': 'Antica Osteria da Divo',
#   'address': 'Via Franciosa 25',
#   'rating': 4.0,
#   'category': 'Italian'},
#  {'name': 'Ostaria dá Cice',
#   'address': 'Via San Pietro 32',
#   'rating': 4.0,
#   'category': 'Italian'},
#  {'name': 'Mugolone',
#   'address': 'Via dei Pellegrini 8',
#   'rating': 5.0,
#   'category': 'Italian'},
#  {'name': 'Vi Vace',
#   'address': 'Via Stalloreggi 64',
#   'rating': 4.5,
#   'category': 'Pizza'},
#  {'name': 'Bio & Chocolate',
#   'address': 'Via Pantaneto 75',
#   'rating': 5.0,
#   'category': 'Cafes'},
#  {'name': 'Prètto',
#   'address': 'Via dei Termini 4',
#   'rating': 4.0,
#   'category': 'Salumerie'},
#  {'name': 'Ristorante San Desiderio',
#   'address': 'Piazza L. Bonelli 2',
#   'rating': 4.0,
#   'category': 'Italian'},
#  {'name': 'Osteria Le Logge',
#   'address': 'Via del Porrione 33',
#   'rating': 4.0,
#   'category': 'Italian'},
#  {'name': 'Taverna di Cecco',
#   'address': 'Via Cecco Angliolieri 19',
#   'rating': 4.5,
#   'category': 'Tuscan'},
#  {'name': 'Antica Salumeria Salvini Ciofi Soccol e Zanolli',
#   'address': 'Str. Statale 73 Ponente, 46',
#   'rating': 3.0},
#  {'name': 'Il Tocco',
#   'address': 'Via Cassia Sud 122',
#   'rating': 4.0,
#   'category': 'Pizza'},
#  {'name': 'Dopolavoro La Foce',
#   'address': 'Strada della Vittorio 90',
#   'rating': 5.0,
#   'category': 'Italian'},
#  {'name': 'la veranda',
#   'address': 'Piazza Calabria',
#   'rating': 4.5,
#   'category': 'Italian'},
#  {'name': "Skile' Music Bar",
#   'address': 'Piazza Calabria 18',
#   'rating': 3.0,
#   'category': 'Cafes'},
#  {'name': 'Hotel Garden',
#   'address': 'Via Custoza 2',
#   'rating': 3.0,
#   'category': 'Venues & Event Spaces'},
#  {'name': 'la veranda',
#   'address': 'Piazza Calabria',
#   'rating': 4.5,
#   'category': 'Italian'},
#  {'name': 'Fontebecci',
#   'address': 'Via Fiorentina 133',
#   'rating': 2.0,
#   'category': 'Pizza'},
#  {'name': "Mc Donald's",
#   'address': 'Via Fiorentina 124',
#   'rating': 2.0,
#   'category': 'Fast Food'},
#  {'name': 'Bar Cecco',
#   'address': 'Viale Camillo Benso Conte Di Cavour',
#   'rating': 3.0,
#   'category': 'Cafes'},
#  {'name': "Skile' Music Bar",
#   'address': 'Piazza Calabria 18',
#   'rating': 3.0,
#   'category': 'Cafes'}]

# %% [markdown]
# Put your parsed results into a DataFrame

# %%
df_yelp = pd.DataFrame(yelp_res_lst)
df_yelp
# Out:
#                            name                              address  rating  \
# 0    La Taverna di San Giuseppe               Via Giovanni Dupre 132     5.0
# 1                          Zest             Costa di Sant'antonio 13     4.5
# 2                La Chiacchiera           Via Costa di San Antonio 4     4.0
# 3                  Café Nannini                  Piazza Matteotti 32     4.5
# 4      Compagnia dei Vinattieri                  Via delle Terme, 79     4.0
# ..                          ...                                  ...     ...
# 218                  la veranda                      Piazza Calabria     4.5
# 219                  Fontebecci                   Via Fiorentina 133     2.0
# 220                 Mc Donald's                   Via Fiorentina 124     2.0
# 221                   Bar Cecco  Viale Camillo Benso Conte Di Cavour     3.0
# 222            Skile' Music Bar                   Piazza Calabria 18     3.0
#
#       category
# 0       Tuscan
# 1      Italian
# 2      Italian
# 3        Cafes
# 4       Tuscan
# ..         ...
# 218    Italian
# 219      Pizza
# 220  Fast Food
# 221      Cafes
# 222      Cafes
#
# [223 rows x 4 columns]

# %% [markdown]
# # Comparing Results

# %% [markdown]
# Which API provided you with more complete data? Provide an explanation.

# %%
df_foursquare.shape
# Out:
# (190, 3)

# %%
df_yelp.shape
# Out:
# (223, 4)

# %% [markdown]
# Yelp provides more data. It has 223 rows wihle Foursquare provides 199 rows

# %% [markdown]
# Get the top 10 restaurants according to their rating

# %%
df_yelp.sort_values(by='rating', ascending=False).head(10)
# Out:
#                              name                        address  rating  \
# 0      La Taverna di San Giuseppe         Via Giovanni Dupre 132     5.0
# 138                  Ravioli Wang  Viale Vittorio Emanuele II 38     5.0
# 168                L'oro di Siena               Via Garibaldi 61     5.0
# 37                       Mugolone           Via dei Pellegrini 8     5.0
# 40     La Taverna di San Giuseppe         Via Giovanni Dupre 132     5.0
# 159  Antica Trattoria Botteganova         Strada Chiantigiana 29     5.0
# 154                 Cartazucchero                Via Camollia 92     5.0
# 47                 Duomo di Siena             Piazza del Duomo 8     5.0
# 153                   La Mandorla                Via Camollia 36     5.0
# 151                   Pasta Mondo               Via Camollia 173     5.0
#
#                              category
# 0                              Tuscan
# 138                           Chinese
# 168                             Pizza
# 37                            Italian
# 40                             Tuscan
# 159                           Italian
# 154                    Used Bookstore
# 47   Landmarks & Historical Buildings
# 153                          Desserts
# 151                             Pizza
